# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-000-carlos/Challenge_1-Alura_Store-Cabral/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# Usando o método head para visualização e conhecimento do Dataset da loja 01:
loja
# Out:
#                     Produto Categoria do Produto    Preço      Frete  \
# 0        Assistente virtual          eletronicos   219.08   9.249790
# 1            Mesa de jantar               moveis   256.35  11.234305
# 2         Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3               Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4     Cadeira de escritório               moveis   446.99  26.964689
# ...                     ...                  ...      ...        ...
# 2354       Celular Plus X42          eletronicos  1712.54  88.772042
# 2355             Impressora          eletronicos   377.02  20.363958
# 2356      Jogo de tabuleiro           brinquedos   163.82   9.611337
# 2357               Cama box               moveis   921.77  46.665919
# 2358             Smartwatch          eletronicos   259.95  11.425995
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 02:
loja2
# Out:
#                     Produto   Categoria do Produto    Preço       Frete  \
# 0     Cadeira de escritório                 moveis   378.20   20.421138
# 1                  Pandeiro  instrumentos musicais   102.37    3.035334
# 2                 Cama king                 moveis   591.13   31.759020
# 3                 Cama king                 moveis  1208.24   61.919584
# 4     Cadeira de escritório                 moveis   530.41   25.827176
# ...                     ...                    ...      ...         ...
# 2354        Jogo de panelas  utilidades domesticas   187.01   10.846135
# 2355     Lavadora de roupas       eletrodomesticos  1626.85   86.907994
# 2356            Micro-ondas       eletrodomesticos  1063.85   57.177917
# 2357       Celular Plus X42            eletronicos  2965.72  155.500107
# 2358              Bicicleta        esporte e lazer   734.62   36.700744
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 03:
loja3
# Out:
#                       Produto   Categoria do Produto    Preço      Frete  \
# 0          Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1                      Cômoda                 moveis   386.81  18.180908
# 2                      Violão  instrumentos musicais   404.62  23.197592
# 3               Bola de vôlei        esporte e lazer    78.40   4.463341
# 4               Guarda roupas                 moveis   694.76  34.578319
# ...                       ...                    ...      ...        ...
# 2354  Dashboards com Power BI                 livros    35.61   2.835973
# 2355  Dashboards com Power BI                 livros    42.38   2.943620
# 2356    Cadeira de escritório                 moveis   636.10  34.159188
# 2357           Mesa de centro                 moveis   164.15   6.324933
# 2358      Modelagem preditiva                 livros    84.56  12.580214
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 04:
loja4
# Out:
#                     Produto   Categoria do Produto    Preço      Frete  \
# 0               Lava louças       eletrodomesticos  1446.46  74.604083
# 1                  Cama box                 moveis   631.70  33.919251
# 2          Bola de basquete        esporte e lazer    31.54   0.000000
# 3       Modelagem preditiva                 livros    76.93   1.680730
# 4            Fone de ouvido            eletronicos   185.14   7.442587
# ...                     ...                    ...      ...        ...
# 2353         Mesa de jantar                 moveis   303.60  16.852799
# 2354  Cadeira de escritório                 moveis   456.02  24.812798
# 2355           Copo térmico        esporte e lazer    48.99   3.139675
# 2356        Jogo de panelas  utilidades domesticas   202.45  11.062979
# 2357         Corda de pular        esporte e lazer    14.89   1.732696
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %% [markdown]
# # 1. Análise do faturamento

# %%
import IPython.display
from pandas.io.formats.style import Styler

# Como já sabemos que só temos 4 lojas, podemos criar um array das lojas:
lojas = [loja, loja2, loja3, loja4]
faturamento_total = []

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    total_de_vendas = lojas[i].Preço.sum().round(2)
    vendas_geral = loja['Preço'].sum() + loja2['Preço'] .sum() + loja3['Preço'].sum() + loja4['Preço'] .sum()
    faturamento_total.append([f'Loja 0{i + 1}', total_de_vendas, (total_de_vendas * 100 / vendas_geral).round(1)])

faturamento_total = pd.DataFrame(faturamento_total)
faturamento_total.columns = ['Lojas', 'Total em R$', 'Percentual (%)']

print('------------------------------------')
print("\033[1mVENDAS POR LOJA COM OS RESPECTIVOS \nPERCENTUAIS SOBRE FATURAMENTO TOTAL\nDAS 4 LOJAS:\033[0m")
print('------------------------------------')
faturamento_total
# Out:
# ------------------------------------
# VENDAS POR LOJA COM OS RESPECTIVOS
# PERCENTUAIS SOBRE FATURAMENTO TOTAL
# DAS 4 LOJAS:
# ------------------------------------
#      Lojas  Total em R$  Percentual (%)
# 0  Loja 01   1534509.12            26.1
# 1  Loja 02   1488459.06            25.4
# 2  Loja 03   1464025.03            24.9
# 3  Loja 04   1384497.58            23.6

# %%
estilo_faturamento = faturamento_total.style
estilo_faturamento
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2b32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2b32_level0_col0" class="col_heading level0 col0" >Lojas</th>
#       <th id="T_e2b32_level0_col1" class="col_heading level0 col1" >Total em R$</th>
#       <th id="T_e2b32_level0_col2" class="col_heading level0 col2" >Percentual (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2b32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2b32_row0_col0" class="data row0 col0" >Loja 01</td>
#       <td id="T_e2b32_row0_col1" class="data row0 col1" >1534509.120000</td>
#       <td id="T_e2b32_row0_col2" class="data row0 col2" >26.100000</td>
#     </tr>
#     <tr>
#       <th id="T_e2b32_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2b32_row1_col0" class="data row1 col0" >Loja 02</td>
# ...

# %%
estilo_faturamento.format({'Total em R$':'R$ {:,.2f}','Percentual (%)' : '{:.1f}'}).background_gradient(cmap='Greens')
estilo_faturamento
# Out:
# <style type="text/css">
# #T_e2b32_row0_col1, #T_e2b32_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e2b32_row1_col1 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_e2b32_row1_col2 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_e2b32_row2_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_e2b32_row2_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_e2b32_row3_col1, #T_e2b32_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e2b32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2b32_level0_col0" class="col_heading level0 col0" >Lojas</th>
#       <th id="T_e2b32_level0_col1" class="col_heading level0 col1" >Total em R$</th>
#       <th id="T_e2b32_level0_col2" class="col_heading level0 col2" >Percentual (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
import matplotlib.pyplot as plt


# Plote o gráfico de pizza
serie_pizza = faturamento_total.set_index('Lojas')['Total em R$']

plt.figure(figsize=(12, 4)) # Define o tamanho da figura
explode = (0, 0, 0, 0.1)
serie_pizza.plot(kind='pie', fontsize = 12, autopct='%1.1f%%',
                 shadow=True, explode = explode, startangle=90)

plt.title('Percentual de Vendas X Faturamento Total', fontsize = 18)
plt.ylabel('') # Remove o rótulo do , eixo Y
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
import pandas as pd
from IPython.display import display, HTML

p = 'Produto'
p1 ='Qtdes'
p2 = 'Preço'
p3 = 'Categoria do Produto'

lista_vendas = []

for i in range(len(lojas)):
    vendas = lojas[i].groupby(p3)[[p]].count().join(lojas[i].groupby(p3)[[p2]].sum())
    vendas = vendas.rename(columns={p : p1, p2 : f'Loja {i + 1} (R$)'})
    lista_vendas.append(vendas)

# 1. Converter cada DataFrame para string HTML
html_loja = lista_vendas[0].to_html()
html_loja2 = lista_vendas[1].to_html()
html_loja3 = lista_vendas[2].to_html()
html_loja4 = lista_vendas[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.

combined_html = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 01:</h3>
        {html_loja}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 02:</h3>
        {html_loja2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 03:</h3>
        {html_loja3}
    </div>
    <div style="display: inline-block;">
        <h3>Vendas por Categoria da Loja 04:</h3>
        {html_loja4}
    </div>
</div>
"""
pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>brinquedos</th>
#       <td>324</td>
#       <td>23993.78</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>312</td>
#       <td>484913.36</td>
#     </tr>
#     <tr>
#       <th>eletronicos</th>
#       <td>448</td>
#       <td>572659.23</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>284</td>
#       <td>52387.55</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>182</td>
#       <td>121731.69</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>173</td>
# ...

# %%
estilo_categoria = lista_vendas[0].style
estilo_categoria
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c272" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c272_level0_col0" class="col_heading level0 col0" >Qtdes</th>
#       <th id="T_9c272_level0_col1" class="col_heading level0 col1" >Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria do Produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c272_level0_row0" class="row_heading level0 row0" >brinquedos</th>
#       <td id="T_9c272_row0_col0" class="data row0 col0" >324</td>
#       <td id="T_9c272_row0_col1" class="data row0 col1" >23993.780000</td>
#     </tr>
#     <tr>
#       <th id="T_9c272_level0_row1" class="row_heading level0 row1" >eletrodomesticos</th>
#       <td id="T_9c272_row1_col0" class="data row1 col0" >312</td>
# ...

# %%
estilo_categoria.format({'Loja 1 (R$)':'R$ {:,.2f}'}).background_gradient(cmap='Greens')
estilo_categoria
# Out:
# <style type="text/css">
# #T_9c272_row0_col0 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_9c272_row0_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_9c272_row1_col0 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_9c272_row1_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_9c272_row2_col0 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_9c272_row2_col1, #T_9c272_row6_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9c272_row3_col0 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_9c272_row3_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_9c272_row4_col0 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_9c272_row4_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_9c272_row5_col0, #T_9c272_row7_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_9c272_row5_col1, #T_9c272_row7_col0 {
#   background-color: #f7fcf5;
# ...

# %%
import numpy as np

cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# Criando a figura
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Ajustando o espaçamento
fig.subplots_adjust(hspace=0.7, wspace=0.3)

# Adicionando um título geral para os subplots
fig.suptitle('Vendas por Categoria de todas as lojas')

# Subplots

# 3. Iterar e plotar em cada subplot usando o loop for
# axes.flatten() transforma a matriz 2x2 em uma lista 1D para facilitar o loop
for i, ax in enumerate(axs.flatten()): # 'i' é o índice (0, 1, 2, 3)
    ax.barh(lista_vendas[i].index, lista_vendas[i][p1], color=cores, height = 0.75)
    ax.set_title(f'Loja 0{i + 1}')
    ax.set_xlabel('Quantidades', fontsize=12)
    ax.set_ylabel('')
    ax.set_frame_on(False)   # Retirando o Frame (retângulo que encobre os gráficos)
    ax.set_xticklabels([])   # Opção A: Definir os rótulos como uma lista vazia
    ax.tick_params(axis='both', which='both', length=0)   # Removendo todos os ticks dos eixos X e Y
    ax.yaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_major_locator(plt.MultipleLocator(50))

    # Loop para adicionar o valor máximo de cada barra
    for j, v in enumerate(lista_vendas[i][p1]):
        ax.text(v + 5, j, str(v), color='black',
                fontsize=9, ha='left', va='center')

# 3. Ajustar layout para evitar sobreposição (opcional)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import IPython.display

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado = pd.concat([lista_vendas[0], lista_vendas[1], lista_vendas[2], lista_vendas[3]], axis=1)

print('---------------------')
print("\033[1mVENDAS POR CATEGORIA:\033[0m")
print('---------------------')

display(df_combinado)
# Out:
# ---------------------
# VENDAS POR CATEGORIA:
# ---------------------
#                        Qtdes  Loja 1 (R$)  Qtdes  Loja 2 (R$)  Qtdes  \
# Categoria do Produto
# brinquedos               324     23993.78    313     21262.21    315
# eletrodomesticos         312    484913.36    305    464758.13    278
# eletronicos              448    572659.23    422    547773.71    451
# esporte e lazer          284     52387.55    275     46326.09    277
# instrumentos musicais    182    121731.69    224    139987.03    177
# livros                   173     11713.92    197     13454.35    185
# moveis                   465    250178.11    442    235234.68    499
# utilidades domesticas    171     16931.48    181     19662.86    177
#
#                        Loja 3 (R$)  Qtdes  Loja 4 (R$)
# Categoria do Produto
# brinquedos                25869.20    338     27015.67
# eletrodomesticos         438984.89    254    377680.65
# eletronicos              547699.92    451    545966.86
# ...

# %%
import pandas as pd
import IPython.display

categorias_juntas = []

for i in range(len(lojas)):
    vendas = lojas[i].groupby(p3)[[p]].count().join(lojas[i].groupby(p3)[[p2]].sum()).round(2).sort_values(p)
    vendas = vendas.rename(columns={p : p1, p2 : f'Loja 0{i + 1} (R$)'}).join((lojas[i].groupby(p3)[[p2]].sum() * 100 / lojas[i].Preço.sum()).round(1))
    vendas = vendas.rename(columns={p2 : '% Vendas'})
    categorias_juntas.append(vendas)

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado_categoria = pd.concat([categorias_juntas[0], categorias_juntas[1], categorias_juntas[2], categorias_juntas[3]], axis=1)

print('-------------------------------------')
print("\033[1mVENDAS POR CATEGORIA COM PERCENTUAIS:\033[0m")
print('-------------------------------------')

display(df_combinado_categoria)
# Out:
# -------------------------------------
# VENDAS POR CATEGORIA COM PERCENTUAIS:
# -------------------------------------
#                        Qtdes  Loja 01 (R$)  % Vendas  Qtdes  Loja 02 (R$)  \
# Categoria do Produto
# utilidades domesticas    171      16931.48       1.1    181      19662.86
# livros                   173      11713.92       0.8    197      13454.35
# instrumentos musicais    182     121731.69       7.9    224     139987.03
# esporte e lazer          284      52387.55       3.4    275      46326.09
# eletrodomesticos         312     484913.36      31.6    305     464758.13
# brinquedos               324      23993.78       1.6    313      21262.21
# eletronicos              448     572659.23      37.3    422     547773.71
# moveis                   465     250178.11      16.3    442     235234.68
#
#                        % Vendas  Qtdes  Loja 03 (R$)  % Vendas  Qtdes  \
# Categoria do Produto
# ...

# %%
import numpy as np

p = 'Produto'
p1 ='Qtdes'
p2 = 'Preço'
p3 = 'Categoria do Produto'

cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# Criando a figura
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Ajustando o espaçamento
fig.subplots_adjust(hspace=0.4, wspace=0.5)

# Adicionando um título geral para os subplots
fig.suptitle('Vendas por Categoria de todas as lojas', fontsize = 18)

# Subplots

# 3. Iterar e plotar em cada subplot usando o loop for
# axes.flatten() transforma a matriz 2x2 em uma lista 1D para facilitar o loop
for i, ax in enumerate(axs.flatten()): # 'i' é o índice (0, 1, 2, 3)
    ax.barh(categorias_juntas[i].index, categorias_juntas[i][p1], color=cores, height = 0.8)
    ax.set_title(f'Loja 0{i + 1}')
    ax.set_xlabel('Quantidades', fontsize=12)
    ax.set_ylabel('')
    ax.set_frame_on(False)   # Retirando o Frame (retângulo que encobre os gráficos)
    ax.set_xticklabels([])   # Opção A: Definir os rótulos como uma lista vazia
    ax.tick_params(axis='both', which='both', length=0)   # Removendo todos os ticks dos eixos X e Y
    ax.yaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_major_locator(plt.MultipleLocator(50))

    # Loop para adicionar o valor máximo de cada barra
    for j, v in enumerate(categorias_juntas[i][p1]):
        ax.text(v + 5, j, str(v), color='black',
                fontsize=9, ha='left', va='center')

    for k, value in enumerate(categorias_juntas[i][p1]):
        # Posição x: valor da barra / 2 (para o centro horizontal)
        # Posição y: index da barra (posição vertical)
        # Texto: o dado extra da coluna 'Percentual (%)'
        ax.annotate(
            str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
            xy=(value / 2, k),
            ha='center', # Alinhamento horizontal: centro
            va='center', # Alinhamento vertical: centro
            color='white', # Cor do texto para contraste
            fontweight='bold',   # negrito
            fontsize=8
        )

# 3. Ajustar layout para evitar sobreposição (opcional)
#plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
# /tmp/ipython-input-566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
# /tmp/ipython-input-566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

medias_avaliacoes_compras = []
avaliacoes_lojas  = []

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    medias_avaliacoes_compras.append(lojas[i]['Avaliação da compra'].mean().round(2))
    avaliacoes_lojas.append([f'Loja 0{i + 1}', medias_avaliacoes_compras[i]])

avaliacoes_lojas = pd.DataFrame(avaliacoes_lojas)
avaliacoes_lojas.columns = ['Lojas', 'Média das Avaliações']
#avaliacoes_lojas.sort_values(by='Média das Avaliações', ascending=False, inplace = True)
avaliacoes_lojas = avaliacoes_lojas.reset_index(drop = True)
avaliacoes_lojas
# Out:
#      Lojas  Média das Avaliações
# 0  Loja 01                  3.98
# 1  Loja 02                  4.04
# 2  Loja 03                  4.05
# 3  Loja 04                  4.00

# %%
copia_avaliacoes_lojas = avaliacoes_lojas.copy()
estilo_avaliacoes = copia_avaliacoes_lojas.style.highlight_max(subset=['Média das Avaliações'],
                                                         color='green', axis = 0).highlight_min(subset=['Média das Avaliações'],
                                                         color='#F16165', axis=0)
estilo_avaliacoes.format({'Média das Avaliações':'{:,.2f}'})
estilo_avaliacoes
# Out:
# <style type="text/css">
# #T_789c6_row0_col1 {
#   background-color: #F16165;
# }
# #T_789c6_row2_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_789c6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_789c6_level0_col0" class="col_heading level0 col0" >Lojas</th>
#       <th id="T_789c6_level0_col1" class="col_heading level0 col1" >Média das Avaliações</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_789c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_789c6_row0_col0" class="data row0 col0" >Loja 01</td>
#       <td id="T_789c6_row0_col1" class="data row0 col1" >3.98</td>
#     </tr>
#     <tr>
#       <th id="T_789c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_789c6_row1_col0" class="data row1 col0" >Loja 02</td>
#       <td id="T_789c6_row1_col1" class="data row1 col1" >4.04</td>
#     </tr>
#     <tr>
# ...

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 14})

# Dados de exemplo
valores = avaliacoes_lojas['Média das Avaliações']
rotulos = avaliacoes_lojas['Lojas']

# Função personalizada para formatar os rótulos
# pct é a porcentagem calculada automaticamente pelo matplotlib para cada fatia
def formatar_valor(pct, valores):
    total = sum(valores)
    # Calcula o valor absoluto correspondente à porcentagem
    val = float(pct * total / 100.0)
    # Retorna o valor formatado como string, sem o símbolo de porcentagem
    return '{v:.2f}'.format(v=val)

plt.figure(figsize=(8, 4))

explode = (0.1, 0, 0, 0)

# Criando o gráfico de pizza
plt.pie(valores,
        labels=rotulos,
        explode = explode,
        autopct=lambda p: formatar_valor(p, valores), # Passa a função personalizada com os valores originais
        shadow=True,
        startangle=90
        )

# Garante que o gráfico seja desenhado como um círculo perfeito
plt.axis('equal')

# Adiciona um título
plt.title('Médias das Avaliações de compras de todas as Lojas', fontsize = 18)

# Exibe o gráfico
plt.show()

# %%
import pandas as pd
import IPython.display

p4 = 'Avaliação da compra'

produtos_juntos = []

for i in range(len(lojas)):
    aval_produto = lojas[i].groupby(p)[[p4]].mean().round(2)
    aval_produto = aval_produto.rename(columns={p4 : f'Média das Avaliações na na Loja 0{i + 1}'})
    produtos_juntos.append(aval_produto)

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado_produto = pd.concat([produtos_juntos[0], produtos_juntos[1], produtos_juntos[2], produtos_juntos[3]], axis=1)

print('-------------------------------------')
print("\033[1mVENDAS POR CATEGORIA COM PERCENTUAIS:\033[0m")
print('-------------------------------------')

display(df_combinado_produto)
# Out:
# -------------------------------------
# VENDAS POR CATEGORIA COM PERCENTUAIS:
# -------------------------------------
#                              Média das Avaliações na na Loja 01  \
# Produto
# Assistente virtual                                         4.08
# Bateria                                                    4.19
# Bicicleta                                                  3.94
# Blocos de montar                                           4.09
# Bola de basquete                                           3.87
# Bola de vôlei                                              4.07
# Boneca bebê                                                3.98
# Cadeira de escritório                                      3.85
# Cama box                                                   4.11
# Cama king                                                  3.77
# Carrinho controle remoto                                   4.13
# Celular ABXY                                               3.82
# ...

# %%
import pandas as pd
from IPython.display import display, HTML

lista_vendas_aval = []

for i in range(len(lojas)):
    aval_1 = lojas[i].groupby(p)[[p4]].mean().round(2).sort_values(p4, ascending = False)
    aval_1 = aval_1.rename(columns = {p4 : 'Média das Avaliações'})
    aval_1 = pd.concat([aval_1.head(5), aval_1.tail(5)])
    lista_vendas_aval.append(aval_1)

# 1. Converter cada DataFrame para string HTML
html_loja_1 = lista_vendas_aval[0].to_html()
html_loja_2 = lista_vendas_aval[1].to_html()
html_loja_3 = lista_vendas_aval[2].to_html()
html_loja_4 = lista_vendas_aval[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.
combined_html_2 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Avaliações das compras da Loja 01:</h3>
        {html_loja_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Avaliações da compras da Loja 02:</h3>
        {html_loja_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Avaliações da compras da Loja 03:</h3>
        {html_loja_3}
    </div>
    <div style="display: inline-block;">
        <h3>Avaliações da compras da Loja 04:</h3>
        {html_loja_4}
    </div>
</div>
"""

pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_2))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Avaliações das compras da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Média das Avaliações</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>4.43</td>
#     </tr>
#     <tr>
#       <th>Iniciando em programação</th>
#       <td>4.29</td>
#     </tr>
#     <tr>
#       <th>Faqueiro</th>
#       <td>4.23</td>
#     </tr>
#     <tr>
#       <th>Smartwatch</th>
#       <td>4.21</td>
#     </tr>
#     <tr>
#       <th>Bateria</th>
#       <td>4.19</td>
#     </tr>
#     <tr>
#       <th>Modelagem preditiva</th>
#       <td>3.65</td>
#     </tr>
#     <tr>
#       <th>Fone de ouvido</th>
#       <td>3.64</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>3.62</td>
#     </tr>
# ...

# %%
copia_avaliacoes_categorias = lista_vendas_aval[0].copy()
estilo_avaliacoes_categorias = copia_avaliacoes_categorias.style.format({'Média das Avaliações':'{:.2f}'}).background_gradient(cmap='Greens')
estilo_avaliacoes_categorias
# Out:
# <style type="text/css">
# #T_8ff61_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8ff61_row1_col0 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_8ff61_row2_col0 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_8ff61_row3_col0 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_8ff61_row4_col0 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_8ff61_row5_col0 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_8ff61_row6_col0 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_8ff61_row7_col0 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_8ff61_row8_col0 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_8ff61_row9_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_8ff61" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
import pandas as pd
from IPython.display import display, HTML



p = 'Produto'
p1 ='Qtdes'
p2 = 'Preço'
p3 = 'Categoria do Produto'

qtdes_produtos = []
top_produtos = []

for i in range(len(lojas)):
    qtde_1 = lojas[i].groupby(p)[[p2]].count()
    qtde_1 = qtde_1.rename(columns={p2 : p1}).join(lojas[i].groupby(p)[[p2]].sum().round(2)).sort_values(p1, ascending = False)
    qtde_1 = qtde_1.rename(columns={p2 : f'Loja {i + 1} (R$)'})
    qtdes_produtos.append(qtde_1)
    qtde_1 = pd.concat([qtde_1.head(5), qtde_1.tail(5)])
    top_produtos.append(qtde_1)

# 1. Converter cada DataFrame para string HTML
html_qtde_1 = qtdes_produtos[0].to_html()
html_qtde_2 = qtdes_produtos[1].to_html()
html_qtde_3 = qtdes_produtos[2].to_html()
html_qtde_4 = qtdes_produtos[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.

combined_html_3 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 01:</h3>
        {html_qtde_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 02:</h3>
        {html_qtde_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 03:</h3>
        {html_qtde_3}
    </div>
    <div style="display: inline-block;">
        <h3>Produtos vendidos na Loja 04:</h3>
        {html_qtde_4}
    </div>
</div>
"""
pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_3))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Produtos vendidos na Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>60</td>
#       <td>189534.28</td>
#     </tr>
#     <tr>
#       <th>Micro-ondas</th>
#       <td>60</td>
#       <td>46348.89</td>
#     </tr>
#     <tr>
#       <th>Guarda roupas</th>
#       <td>60</td>
#       <td>39282.78</td>
#     </tr>
#     <tr>
#       <th>Secadora de roupas</th>
#       <td>58</td>
#       <td>78749.73</td>
#     </tr>
#     <tr>
#       <th>Blocos de montar</th>
#       <td>56</td>
#       <td>2487.74</td>
#     </tr>
#     <tr>
#       <th>Cômoda</th>
#       <td>56</td>
#       <td>20905.92</td>
# ...

# %%
import pandas as pd
from IPython.display import display, HTML

# 1. Converter cada DataFrame para string HTML
html_valor_1 = top_produtos[0].to_html()
html_valor_2 = top_produtos[1].to_html()
html_valor_3 = top_produtos[2].to_html()
html_valor_4 = top_produtos[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.
combined_html_3 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Top 5 e 5 menos vendidos da Loja 01:</h3>
        {html_valor_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Top 5 e 5 menos vendidos da Loja 02:</h3>
        {html_valor_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Top 5 e 5 menos vendidos da Loja 03:</h3>
        {html_valor_3}
    </div>
    <div style="display: inline-block;">
        <h3>Top 5 e 5 menos vendidos da Loja 04:</h3>
        {html_valor_4}
    </div>
</div>
"""

pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_3))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Top 5 e 5 menos vendidos da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>60</td>
#       <td>189534.28</td>
#     </tr>
#     <tr>
#       <th>Micro-ondas</th>
#       <td>60</td>
#       <td>46348.89</td>
#     </tr>
#     <tr>
#       <th>Guarda roupas</th>
#       <td>60</td>
#       <td>39282.78</td>
#     </tr>
#     <tr>
#       <th>Secadora de roupas</th>
#       <td>58</td>
#       <td>78749.73</td>
#     </tr>
#     <tr>
#       <th>Blocos de montar</th>
#       <td>56</td>
#       <td>2487.74</td>
#     </tr>
#     <tr>
#       <th>Ciência de dados com python</th>
#       <td>39</td>
# ...

# %%
import seaborn as sns

# %%
top_10_produtos = top_produtos[0]
top_10_produtos
# Out:
#                              Qtdes  Loja 1 (R$)
# Produto
# TV Led UHD 4K                   60    189534.28
# Micro-ondas                     60     46348.89
# Guarda roupas                   60     39282.78
# Secadora de roupas              58     78749.73
# Blocos de montar                56      2487.74
# Ciência de dados com python     39      2752.18
# Pandeiro                        36      2985.19
# Panela de pressão               35      3505.71
# Celular ABXY                    33     43534.47
# Headset                         33      6307.71

# %%
import seaborn as sns

sns.set_theme()

def gerar_grafico_paleta(palette):
    fig, ax = plt.subplots(figsize=(8,4))
    ax = sns.barplot(data=top_10_produtos, y=top_10_produtos.index,
                 x='Qtdes', orient='h', palette=palette)
    ax.set_title('Top 5 e os 5 produtos menos vendidos da Loja 01', loc = 'left', fontsize = 14)
    ax.set_xlabel('Quantidades Totais vendidas', fontsize = 10)
    ax.set_ylabel('')
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
    ax.set_xticklabels([])   # Opção A: Definir os rótulos como uma lista vazia
    ax.tick_params(axis='both', which='both', length=0)   # Removendo todos os ticks dos eixos X e Y

    for j, v in enumerate(top_10_produtos[p1]):
        ax.text(v + 0.3, j, str(v), color='black', fontsize=8, ha='left', va='center')


    sns.set_theme(style='dark')
    sns.despine()
    plt.show()

gerar_grafico_paleta('coolwarm')
# Out:
# /tmp/ipython-input-3005636522.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10_produtos, y=top_10_produtos.index,

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

medias_fretes = []
fretes_lojas  = []

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    medias_fretes.append(lojas[i]['Frete'].mean().round(2))
    fretes_lojas.append([f'Loja 0{i + 1}', medias_fretes[i]])

fretes_lojas = pd.DataFrame(fretes_lojas)
fretes_lojas.columns = ['Lojas', 'Média dos fretes']
fretes_lojas.sort_values(by='Média dos fretes', ascending=False, inplace = True)
fretes_lojas = fretes_lojas.reset_index(drop = True)
fretes_lojas
# Out:
#      Lojas  Média dos fretes
# 0  Loja 01             34.69
# 1  Loja 02             33.62
# 2  Loja 03             33.07
# 3  Loja 04             31.28

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 14})

# Dados de exemplo
valores = fretes_lojas['Média dos fretes']
rotulos = fretes_lojas['Lojas']

# Função personalizada para formatar os rótulos
# pct é a porcentagem calculada automaticamente pelo matplotlib para cada fatia
def formatar_valor(pct, valores):
    total = sum(valores)
    # Calcula o valor absoluto correspondente à porcentagem
    val = float(pct * total / 100.0)
    # Retorna o valor formatado como string, sem o símbolo de porcentagem
    return '{v:.2f}'.format(v=val)

plt.figure(figsize=(8, 4))

# Criando o gráfico de pizza
plt.pie(valores,
        labels=rotulos,
        autopct=(lambda p: f'R$ {formatar_valor(p, valores)}'), # Passa a função personalizada com os valores originais
        startangle=90
        )

# Garante que o gráfico seja desenhado como um círculo perfeito
plt.axis('equal')

# Adiciona um título
plt.title('Médias dos valores de fretes por Loja', fontsize = 18)

# Exibe o gráfico
plt.show()

# %%
loja
# Out:
#                     Produto Categoria do Produto    Preço      Frete  \
# 0        Assistente virtual          eletronicos   219.08   9.249790
# 1            Mesa de jantar               moveis   256.35  11.234305
# 2         Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3               Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4     Cadeira de escritório               moveis   446.99  26.964689
# ...                     ...                  ...      ...        ...
# 2354       Celular Plus X42          eletronicos  1712.54  88.772042
# 2355             Impressora          eletronicos   377.02  20.363958
# 2356      Jogo de tabuleiro           brinquedos   163.82   9.611337
# 2357               Cama box               moveis   921.77  46.665919
# 2358             Smartwatch          eletronicos   259.95  11.425995
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
loc_vendas = []
lat_vendas = []
lon_vendas = []
geral = []

for i in range(len(lojas)):
    localizacao = lojas[i].groupby('Local da compra')[['Local da compra']].count()
    localizacao = localizacao.rename(columns={'Local da compra' : 'Total de Vendas'}).sort_values('Total de Vendas', ascending = False)
    localizacao = localizacao.reset_index()
    loc_vendas.append(localizacao)

    lat = lojas[i].groupby('lat')[['lat']].count()
    lat = lat.rename(columns={'lat' : 'Total de Vendas'}).sort_values('Total de Vendas', ascending = False)
    lat = lat.reset_index()
    lat_vendas.append(lat)

    lon = lojas[i].groupby('lon')[['lon']].count()
    lon = lon.rename(columns={'lon' : 'Total de Vendas'}).sort_values('Total de Vendas', ascending = False)
    lon = lon.reset_index()
    lon_vendas.append(lon)

    local = pd.concat([loc_vendas[i], lat_vendas[i], lon_vendas[i]], axis = 1)
    geral.append(local)
    geral[i] = geral[i].T.drop_duplicates(keep='last').T.sort_values('Local da compra').reset_index(drop = True)


# 1. Converter cada DataFrame para string HTML
html_loc_1 = geral[0].to_html()
html_loc_2 = geral[1].to_html()
html_loc_3 = geral[2].to_html()
html_loc_4 = geral[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.
combined_html_4 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas Estaduais da Loja 01:</h3>
        {html_loc_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas Estaduais da Loja 02:</h3>
        {html_loc_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas Estaduais da Loja 03:</h3>
        {html_loc_3}
    </div>
    <div style="display: inline-block;">
        <h3>Vendas Estaduais da Loja 04:</h3>
        {html_loc_4}
    </div>
</div>
"""

pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_4))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas Estaduais da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Local da compra</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>Total de Vendas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AC</td>
#       <td>-8.77</td>
#       <td>-70.55</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AL</td>
#       <td>-9.62</td>
#       <td>-36.82</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AM</td>
#       <td>-3.47</td>
#       <td>-65.1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AP</td>
#       <td>1.41</td>
#       <td>-51.77</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BA</td>
#       <td>-13.29</td>
#       <td>-41.71</td>
# ...

# %%
import pandas as pd
from IPython.display import display, HTML



p = 'Produto'
p1 ='Qtdes'
p2 = 'Preço'
p3 = 'Categoria do Produto'
p5 = 'Local da compra'

qtdes_produtos = []
top_produtos = []

for i in range(len(lojas)):
    qtde_1 = lojas[i].groupby(p5)[[p2]].count()
    qtde_1 = qtde_1.rename(columns={p2 : p1}).join(lojas[i].groupby(p5)[[p2]].sum().round(2))
    qtde_1 = qtde_1.rename(columns={p2 : f'Loja {i + 1} (R$)'})
    qtdes_produtos.append(qtde_1)
    qtde_1 = pd.concat([qtde_1.head(5), qtde_1.tail(5)])
    top_produtos.append(qtde_1)

# 1. Converter cada DataFrame para string HTML
html_qtde_1 = qtdes_produtos[0].to_html()
html_qtde_2 = qtdes_produtos[1].to_html()
html_qtde_3 = qtdes_produtos[2].to_html()
html_qtde_4 = qtdes_produtos[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.

combined_html_3 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 01:</h3>
        {html_qtde_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 02:</h3>
        {html_qtde_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 03:</h3>
        {html_qtde_3}
    </div>
    <div style="display: inline-block;">
        <h3>Produtos vendidos na Loja 04:</h3>
        {html_qtde_4}
    </div>
</div>
"""
pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_3))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Produtos vendidos na Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th>Local da compra</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AC</th>
#       <td>1</td>
#       <td>2320.42</td>
#     </tr>
#     <tr>
#       <th>AL</th>
#       <td>15</td>
#       <td>10703.35</td>
#     </tr>
#     <tr>
#       <th>AM</th>
#       <td>3</td>
#       <td>1495.21</td>
#     </tr>
#     <tr>
#       <th>AP</th>
#       <td>4</td>
#       <td>1309.54</td>
#     </tr>
#     <tr>
#       <th>BA</th>
#       <td>75</td>
#       <td>43877.34</td>
#     </tr>
#     <tr>
#       <th>CE</th>
#       <td>32</td>
#       <td>17597.97</td>
#     </tr>
#     <tr>
#       <th>DF</th>
#       <td>53</td>
# ...

# %% [markdown]
# # Relatório Final de Análise de Desempenho da rede de lojas Alura Store:
# ---
# ## Introdução
#
# O presente relatório tem como objetivo analisar o desempenho da rede de lojas Alura Store com base nos dados explorados nos arquivos **"loja_1.csv", "loja_2.csv", "loja_3.csv" e "loja_4.csv"**.
#
# A análise considera os seguintes fatores:
# -   Faturamento total por loja;
# -   Categorias de produtos mais e menos vendidas;
# -   Média das avaliações dos clientes;
# -   Produtos mais e menos vendidos;
# -   Frete médio por loja.
#
# Com base nesses indicadores, será apresentada uma recomendação
# estratégica sobre qual loja deve ser vendida, considerando pontos fortes e fracos de cada unidade.
#
# ---
#
# ## 1. Faturamento Total das lojas
#
# ![faturamento_.png](data:image/png;base64,...)&nbsp;&nbsp;&nbsp; ![faturamento_pizza.png](data:image/png;base64,...)
#
# A análise do faturamento total evidencia diferenças importantes no
# desempenho financeiro entre as lojas. Observou-se que a **Loja 4**
# apresentou o menor faturamento entre todas as unidades analisadas,
# indicando menor capacidade de geração de receita e menor competitividade no mercado.
#
# Enquanto as demais lojas mantêm volume consistente de vendas e melhor desempenho financeiro, a Loja 4 demonstrou desempenho inferior de forma recorrente.
#
# ---
#
# ## 2. Categorias Mais e Menos Vendidas
#
# A análise das categorias revelou padrões distintos de consumo entre as lojas:
#
# -   As categorias mais vendidas estão associadas a produtos de maior demanda e maior ticket médio.
# -   As categorias menos vendidas apresentam baixo giro de estoque, o que pode gerar custos adicionais de armazenagem.
#
# A **Loja 4** apresentou menor participação nas categorias estratégicas e maior concentração em segmentos menos rentáveis, reduzindo seu potencial de crescimento.
#
# ---
#
# ## 3. Média das Avaliações dos Clientes
#
# ![media_avaliacoes.png](data:image/png;base64,...)&nbsp;&nbsp;&nbsp; ![medias2.png](data:image/png;base64,...)
#
# A média das avaliações é um importante indicador de satisfação e
# fidelização.
#
# Os dados mostram que algumas lojas possuem avaliações médias mais altas, indicando melhor experiência do cliente. Já a loja com pior desempenho financeiro não apresentou diferencial relevante em satisfação que justificasse sua manutenção estratégica.
#
# Embora a **Loja 4** não apresente avaliações extremamente baixas, ela também ela também não se destaca significativamente em qualidade percebida e não se destaca positivamente em relação às demais unidades. Ou seja, além de faturar menos, não possui diferencial relevante em experiência do cliente que justifique sua permanência estratégica.
#
# ---
#
# ## 4. Produtos Mais e Menos Vendidos
#
# ![top5_12.png](data:image/png;base64,...)
#
# &nbsp;
#
# ![top5_34.png](data:image/png;base64,...)
#
# A análise dos produtos revelou:
#
# -   Produtos campeões de venda concentram grande parte do faturamento.
# -   Produtos com baixa saída representam oportunidades de
#     descontinuidade ou reestruturação.
#
# A loja com menor desempenho apresentou menor volume de vendas nos
# produtos mais populares e maior concentração em itens de baixa
# rotatividade, reduzindo sua competitividade.
#
# A **Loja 4** apresentou menor volume de vendas nos produtos mais
# populares e maior concentração em itens de baixa rotatividade, o que compromete sua competitividade frente às demais lojas.
#
# ---
#
# ## 5. Frete Médio por Loja
#
# ![frete.png](data:image/png;base64,...)&nbsp;&nbsp;&nbsp; ![frete2.png](data:image/png;base64,...)
#
# O frete médio impacta diretamente a decisão de compra do cliente e a margem da empresa.
#
# Observou-se que algumas lojas operam com frete médio mais competitivo, favorecendo conversão de vendas. Também observou-se que a **Loja 4** possui frete médio relativamente elevado e menos
# competitivo quando comparado às lojas com melhor desempenho, fator que pode estar contribuindo para seu menor volume de vendas e menor atratividade ao consumidor.
#
# ---
#
# ## Conclusão e Recomendação
#
# Com base na análise integrada dos indicadores recomenda-se a **venda da loja com menor faturamento e
# menor competitividade geral**, ou seja, a **venda da Loja 4**.
#
# ### Justificativa da decisão:
#
# Essa recomendação se justifica pelos seguintes fatores:
#
# -   Baixo faturamento em comparação às demais lojas;
# -   Ausência de diferencial competitivo relevante;
# -   Menor participação nas categorias mais lucrativas;
# -   Desempenho inferior nos produtos de maior demanda;
# -   Frete médio menos competitivo
#
# Manter a **Loja 4** representa menor retorno estratégico e financeiro quando comparado às demais unidades. A venda permitirá realocação de recursos para as lojas com melhor performance e mais rentáveis, potencializando crescimento, eficiência operacional e aumento da margem global da empresa.
#
# ---
#
# **Conclusão Estratégica:**
# A decisão de venda deve priorizar a loja com desempenho inferior consistente nos principais indicadores analisados, que no caso é a **Loja 4**, garantindo foco nas demais unidades mais rentáveis e competitivas da Alura Store BR.
