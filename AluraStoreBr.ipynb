# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# Usando o método head para visualização e conhecimento do Dataset da loja 01:
loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                       1 -15.83 -47.86
# 3            boleto                       1 -30.17 -53.50
# 4            boleto                       1 -18.10 -44.38

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 02:
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                      10 -27.45 -50.95
# 3    cartao_credito                      10 -30.17 -53.50
# 4    cartao_credito                       3 -22.19 -48.79

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 03:
loja3.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# 1    cartao_credito                       1 -30.17 -53.50
# 2    cartao_credito                       3 -22.19 -48.79
# 3    cartao_credito                       6 -13.29 -41.71
# 4    cartao_credito                       1 -22.19 -48.79

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 04:
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# 1    cartao_credito                       2 -15.98 -49.86
# 2            boleto                       1 -18.10 -44.38
# 3            boleto                       1 -18.10 -44.38
# 4    cartao_credito                       7 -22.19 -48.79

# %% [markdown]
# # 1. Análise do faturamento

# %%
# Como já sabemos que só temos 4 lojas, podemos criar um array das lojas:
lojas = [loja, loja2, loja3, loja4]

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    total_de_vendas = lojas[i].Preço.sum().round(2)
    print(f'O faturamento total das vendas na loja 0{i + 1} foi de R$ {total_de_vendas}.')
# Out:
# O faturamento total das vendas na loja 01 foi de R$ 1534509.12.
# O faturamento total das vendas na loja 02 foi de R$ 1488459.06.
# O faturamento total das vendas na loja 03 foi de R$ 1464025.03.
# O faturamento total das vendas na loja 04 foi de R$ 1384497.58.

# %% [markdown]
# # 2. Vendas por Categoria

# %%
import pandas as pd
from IPython.display import display, HTML

num = 1

vendas_1 = loja.groupby('Categoria do Produto')[['Produto']].count().join(loja.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_1 = vendas_1.rename(columns={'Produto' : 'Qtdes', 'Preço' : 'Loja 1 (R$)'})
vendas_2 = loja2.groupby('Categoria do Produto')[['Produto']].count().join(loja2.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_2 = vendas_2.rename(columns={'Produto' : 'Qtdes', 'Preço' : 'Loja 2 (R$)'})
vendas_3 = loja3.groupby('Categoria do Produto')[['Produto']].count().join(loja3.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_3 = vendas_3.rename(columns={'Produto' : 'Qtdes', 'Preço' : 'Loja 3 (R$)'})
vendas_4 = loja4.groupby('Categoria do Produto')[['Produto']].count().join(loja4.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_4 = vendas_4.rename(columns={'Produto' : 'Qtdes', 'Preço' : 'Loja 4 (R$)'})

# 1. Converter cada DataFrame para string HTML
html_loja = vendas_1.to_html()
html_loja2 = vendas_2.to_html()
html_loja3 = vendas_3.to_html()
html_loja4 = vendas_4.to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.

combined_html = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 0{num}:</h3>
        {html_loja}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 0{num}:</h3>
        {html_loja2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 0{num}:</h3>
        {html_loja3}
    </div>
    <div style="display: inline-block;">
        <h3>Vendas por Categoria da Loja 0{num}:</h3>
        {html_loja4}
    </div>
</div>
"""
pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>eletronicos</th>
#       <td>448</td>
#       <td>572659.23</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>312</td>
#       <td>484913.36</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>465</td>
#       <td>250178.11</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>182</td>
#       <td>121731.69</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>284</td>
#       <td>52387.55</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>324</td>
#       <td>23993.78</td>
#     </tr>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>171</td>
#       <td>16931.48</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>173</td>
#       <td>11713.92</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 2 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>eletronicos</th>
#       <td>422</td>
#       <td>547773.71</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>305</td>
#       <td>464758.13</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>442</td>
#       <td>235234.68</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>224</td>
#       <td>139987.03</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>275</td>
#       <td>46326.09</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>313</td>
#       <td>21262.21</td>
#     </tr>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>181</td>
#       <td>19662.86</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>197</td>
#       <td>13454.35</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 3 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>eletronicos</th>
#       <td>451</td>
#       <td>547699.92</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>278</td>
#       <td>438984.89</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>499</td>
#       <td>268095.56</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>177</td>
#       <td>103174.45</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>277</td>
#       <td>47456.10</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>315</td>
#       <td>25869.20</td>
#     </tr>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>177</td>
#       <td>20080.21</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>185</td>
#       <td>12664.70</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block;">
#         <h3>Vendas por Categoria da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 4 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>eletronicos</th>
#       <td>451</td>
#       <td>545966.86</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>254</td>
#       <td>377680.65</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>480</td>
#       <td>256705.65</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>170</td>
#       <td>100136.50</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>277</td>
#       <td>44465.65</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>338</td>
#       <td>27015.67</td>
#     </tr>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>201</td>
#       <td>20098.83</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>187</td>
#       <td>12427.77</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# </div>

# %%
import pandas as pd
import IPython.display

vendas_1 = loja.groupby('Categoria do Produto')[['Produto']].count().join(loja.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_1 = vendas_1.rename(columns={'Produto' : 'Qtdes Lj 1', 'Preço' : 'Loja 01 (R$)'})
vendas_2 = loja2.groupby('Categoria do Produto')[['Produto']].count().join(loja2.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_2 = vendas_2.rename(columns={'Produto' : 'Qtdes Lj 2', 'Preço' : 'Loja 02 (R$)'})
vendas_3 = loja3.groupby('Categoria do Produto')[['Produto']].count().join(loja3.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_3 = vendas_3.rename(columns={'Produto' : 'Qtdes Lj 3', 'Preço' : 'Loja 03 (R$)'})
vendas_4 = loja4.groupby('Categoria do Produto')[['Produto']].count().join(loja4.groupby('Categoria \
do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
vendas_4 = vendas_4.rename(columns={'Produto' : 'Qtdes Lj 4', 'Preço' : 'Loja 04 (R$)'})

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado = pd.concat([vendas_1, vendas_2, vendas_3, vendas_4], axis=1)

print("\033[1mVENDAS POR CATEGORIA:\033[0m")
display(df_combinado)
# Out:
# VENDAS POR CATEGORIA:
#                        Qtdes Lj 1  Loja 01 (R$)  Qtdes Lj 2  Loja 02 (R$)  \
# Categoria do Produto
# eletronicos                   448     572659.23         422     547773.71
# eletrodomesticos              312     484913.36         305     464758.13
# moveis                        465     250178.11         442     235234.68
# instrumentos musicais         182     121731.69         224     139987.03
# esporte e lazer               284      52387.55         275      46326.09
# brinquedos                    324      23993.78         313      21262.21
# utilidades domesticas         171      16931.48         181      19662.86
# livros                        173      11713.92         197      13454.35
#
#                        Qtdes Lj 3  Loja 03 (R$)  Qtdes Lj 4  Loja 04 (R$)
# Categoria do Produto
# eletronicos                   451     547699.92         451     545966.86
# eletrodomesticos              278     438984.89         254     377680.65
# moveis                        499     268095.56         480     256705.65
# instrumentos musicais         177     103174.45         170     100136.50
# esporte e lazer               277      47456.10         277      44465.65
# brinquedos                    315      25869.20         338      27015.67
# utilidades domesticas         177      20080.21         201      20098.83
# livros                        185      12664.70         187      12427.77

# %%
import pandas as pd
import IPython.display

categorias_juntas = []

for i in range(len(lojas)):
    venda = lojas[i].groupby('Categoria do Produto')[['Produto']].count().join(lojas[i].groupby('Categoria do Produto')[['Preço']].sum()).sort_values('Preço', ascending = False)
    venda = venda.rename(columns={'Produto' : f'Qtdes Loja 0{i + 1}', 'Preço' : f'Loja 0{i + 1} (R$)'}).join((lojas[i].groupby('Categoria do Produto')[['Preço']].sum() * 100 / lojas[i].Preço.sum()).round(2))
    venda = venda.rename(columns={'Preço' : '% Vendas'})
    categorias_juntas.append(venda)

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado = pd.concat([categorias_juntas[0], categorias_juntas[1], categorias_juntas[2], categorias_juntas[3]], axis=1)

print("\033[1mVENDAS POR CATEGORIA:\033[0m")
display(df_combinado)
# Out:
# VENDAS POR CATEGORIA:
#                        Qtdes Loja 01  Loja 01 (R$)  % Vendas  Qtdes Loja 02  \
# Categoria do Produto
# eletronicos                      448     572659.23     37.32            422
# eletrodomesticos                 312     484913.36     31.60            305
# moveis                           465     250178.11     16.30            442
# instrumentos musicais            182     121731.69      7.93            224
# esporte e lazer                  284      52387.55      3.41            275
# brinquedos                       324      23993.78      1.56            313
# utilidades domesticas            171      16931.48      1.10            181
# livros                           173      11713.92      0.76            197
#
#                        Loja 02 (R$)  % Vendas  Qtdes Loja 03  Loja 03 (R$)  \
# Categoria do Produto
# eletronicos               547773.71     36.80            451     547699.92
# eletrodomesticos          464758.13     31.22            278     438984.89
# moveis                    235234.68     15.80            499     268095.56
# instrumentos musicais     139987.03      9.40            177     103174.45
# esporte e lazer            46326.09      3.11            277      47456.10
# brinquedos                 21262.21      1.43            315      25869.20
# utilidades domesticas      19662.86      1.32            177      20080.21
# livros                     13454.35      0.90            185      12664.70
#
#                        % Vendas  Qtdes Loja 04  Loja 04 (R$)  % Vendas
# Categoria do Produto
# eletronicos               37.41            451     545966.86     39.43
# eletrodomesticos          29.98            254     377680.65     27.28
# moveis                    18.31            480     256705.65     18.54
# instrumentos musicais      7.05            170     100136.50      7.23
# esporte e lazer            3.24            277      44465.65      3.21
# brinquedos                 1.77            338      27015.67      1.95
# utilidades domesticas      1.37            201      20098.83      1.45
# livros                     0.87            187      12427.77      0.90

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# # 5. Frete Médio por Loja
