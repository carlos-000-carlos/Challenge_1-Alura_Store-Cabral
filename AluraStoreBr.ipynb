# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-000-carlos/Challenge_1-Alura_Store-Cabral/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# Usando o método head para visualização e conhecimento do Dataset da loja 01:
loja
# Out:
#                     Produto Categoria do Produto    Preço      Frete  \
# 0        Assistente virtual          eletronicos   219.08   9.249790
# 1            Mesa de jantar               moveis   256.35  11.234305
# 2         Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3               Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4     Cadeira de escritório               moveis   446.99  26.964689
# ...                     ...                  ...      ...        ...
# 2354       Celular Plus X42          eletronicos  1712.54  88.772042
# 2355             Impressora          eletronicos   377.02  20.363958
# 2356      Jogo de tabuleiro           brinquedos   163.82   9.611337
# 2357               Cama box               moveis   921.77  46.665919
# 2358             Smartwatch          eletronicos   259.95  11.425995
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0        16/01/2021     Pedro Gomes              SP                    4
# 1        18/05/2022  Beatriz Moraes              RJ                    1
# 2        15/03/2021      João Souza              DF                    1
# 3        03/05/2022      João Souza              RS                    4
# 4        07/11/2020   Larissa Alves              MG                    5
# ...             ...             ...             ...                  ...
# 2354     15/11/2021    Thiago Silva              RJ                    1
# 2355     18/03/2023  Lucas Oliveira              SP                    5
# 2356     06/07/2021  Lucas Oliveira              PR                    5
# 2357     02/05/2022     Pedro Gomes              RN                    1
# 2358     18/06/2022   Felipe Santos              RS                    4
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0       cartao_credito                       8 -22.19 -48.79
# 1       cartao_credito                       4 -22.25 -42.66
# 2       cartao_credito                       1 -15.83 -47.86
# 3               boleto                       1 -30.17 -53.50
# 4               boleto                       1 -18.10 -44.38
# ...                ...                     ...    ...    ...
# 2354            boleto                       1 -22.25 -42.66
# 2355            boleto                       1 -22.19 -48.79
# 2356    cartao_credito                       4 -24.89 -51.55
# 2357    cartao_credito                       2  -5.81 -36.59
# 2358    cartao_credito                       1 -30.17 -53.50
#
# [2359 rows x 12 columns]

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 02:
loja2
# Out:
#                     Produto   Categoria do Produto    Preço       Frete  \
# 0     Cadeira de escritório                 moveis   378.20   20.421138
# 1                  Pandeiro  instrumentos musicais   102.37    3.035334
# 2                 Cama king                 moveis   591.13   31.759020
# 3                 Cama king                 moveis  1208.24   61.919584
# 4     Cadeira de escritório                 moveis   530.41   25.827176
# ...                     ...                    ...      ...         ...
# 2354        Jogo de panelas  utilidades domesticas   187.01   10.846135
# 2355     Lavadora de roupas       eletrodomesticos  1626.85   86.907994
# 2356            Micro-ondas       eletrodomesticos  1063.85   57.177917
# 2357       Celular Plus X42            eletronicos  2965.72  155.500107
# 2358              Bicicleta        esporte e lazer   734.62   36.700744
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0        04/08/2021      Thiago Silva              MG                    1
# 1        26/11/2020     Bianca Santos              RJ                    3
# 2        22/10/2021      Thiago Silva              SC                    5
# 3        04/05/2022     Larissa Alves              RS                    5
# 4        26/02/2022    Lucas Oliveira              SP                    4
# ...             ...               ...             ...                  ...
# 2354     04/12/2022   Bruno Rodrigues              BA                    5
# 2355     09/02/2020  Isabella Pereira              SP                    4
# 2356     27/09/2022     Bianca Santos              SP                    5
# 2357     21/04/2022        João Souza              RJ                    5
# 2358     03/09/2022     Larissa Alves              MG                    4
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0               boleto                       1 -18.10 -44.38
# 1       cartao_credito                       4 -22.25 -42.66
# 2       cartao_credito                      10 -27.45 -50.95
# 3       cartao_credito                      10 -30.17 -53.50
# 4       cartao_credito                       3 -22.19 -48.79
# ...                ...                     ...    ...    ...
# 2354    cartao_credito                       2 -13.29 -41.71
# 2355    cartao_credito                       5 -22.19 -48.79
# 2356            boleto                       1 -22.19 -48.79
# 2357    cartao_credito                       2 -22.25 -42.66
# 2358    cartao_credito                       1 -18.10 -44.38
#
# [2359 rows x 12 columns]

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 03:
loja3
# Out:
#                       Produto   Categoria do Produto    Preço      Frete  \
# 0          Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1                      Cômoda                 moveis   386.81  18.180908
# 2                      Violão  instrumentos musicais   404.62  23.197592
# 3               Bola de vôlei        esporte e lazer    78.40   4.463341
# 4               Guarda roupas                 moveis   694.76  34.578319
# ...                       ...                    ...      ...        ...
# 2354  Dashboards com Power BI                 livros    35.61   2.835973
# 2355  Dashboards com Power BI                 livros    42.38   2.943620
# 2356    Cadeira de escritório                 moveis   636.10  34.159188
# 2357           Mesa de centro                 moveis   164.15   6.324933
# 2358      Modelagem preditiva                 livros    84.56  12.580214
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0        17/12/2021    Camila Ribeiro              CE                    4
# 1        10/02/2021     Larissa Alves              RS                    3
# 2        22/01/2023    Lucas Oliveira              SP                    5
# 3        22/03/2022       Pedro Gomes              BA                    4
# 4        12/01/2022     Bianca Santos              SP                    1
# ...             ...               ...             ...                  ...
# 2354     21/10/2022   Bruno Rodrigues              SP                    5
# 2355     23/06/2022     Bianca Santos              SC                    5
# 2356     19/02/2023    Camila Ribeiro              DF                    5
# 2357     19/09/2021     Bianca Santos              SP                    4
# 2358     24/05/2022  Mariana Ferreira              RJ                    5
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0       cartao_credito                       4  -5.20 -39.53
# 1       cartao_credito                       1 -30.17 -53.50
# 2       cartao_credito                       3 -22.19 -48.79
# 3       cartao_credito                       6 -13.29 -41.71
# 4       cartao_credito                       1 -22.19 -48.79
# ...                ...                     ...    ...    ...
# 2354    cartao_credito                       1 -22.19 -48.79
# 2355    cartao_credito                       1 -27.45 -50.95
# 2356    cartao_credito                       3 -15.83 -47.86
# 2357    cartao_credito                       8 -22.19 -48.79
# 2358    cartao_credito                      10 -22.25 -42.66
#
# [2359 rows x 12 columns]

# %%
# Usando o método head para visualização e conhecimento do Dataset da loja 04:
loja4
# Out:
#                     Produto   Categoria do Produto    Preço      Frete  \
# 0               Lava louças       eletrodomesticos  1446.46  74.604083
# 1                  Cama box                 moveis   631.70  33.919251
# 2          Bola de basquete        esporte e lazer    31.54   0.000000
# 3       Modelagem preditiva                 livros    76.93   1.680730
# 4            Fone de ouvido            eletronicos   185.14   7.442587
# ...                     ...                    ...      ...        ...
# 2353         Mesa de jantar                 moveis   303.60  16.852799
# 2354  Cadeira de escritório                 moveis   456.02  24.812798
# 2355           Copo térmico        esporte e lazer    48.99   3.139675
# 2356        Jogo de panelas  utilidades domesticas   202.45  11.062979
# 2357         Corda de pular        esporte e lazer    14.89   1.732696
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0        11/11/2022    Rafael Costa              SP                    4
# 1        03/01/2020    Thiago Silva              GO                    5
# 2        25/12/2022   Larissa Alves              MG                    5
# 3        23/11/2021  Lucas Oliveira              MG                    3
# 4        25/04/2022   Bianca Santos              SP                    4
# ...             ...             ...             ...                  ...
# 2353     12/02/2020  Camila Ribeiro              RJ                    5
# 2354     17/05/2022   Felipe Santos              PE                    5
# 2355     03/05/2022  Camila Ribeiro              SP                    5
# 2356     15/06/2020   Bianca Santos              PR                    5
# 2357     17/11/2021   Felipe Santos              SP                    5
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0       cartao_credito                       3 -22.19 -48.79
# 1       cartao_credito                       2 -15.98 -49.86
# 2               boleto                       1 -18.10 -44.38
# 3               boleto                       1 -18.10 -44.38
# 4       cartao_credito                       7 -22.19 -48.79
# ...                ...                     ...    ...    ...
# 2353    cartao_credito                       1 -22.25 -42.66
# 2354    cartao_credito                       3  -8.38 -37.86
# 2355    cartao_credito                       1 -22.19 -48.79
# 2356    cartao_credito                       1 -24.89 -51.55
# 2357    cartao_credito                       1 -22.19 -48.79
#
# [2358 rows x 12 columns]

# %% [markdown]
# # 1. Análise do faturamento

# %%
import IPython.display
from pandas.io.formats.style import Styler

# Como já sabemos que só temos 4 lojas, podemos criar um array das lojas:
lojas = [loja, loja2, loja3, loja4]
faturamento_total = []

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    total_de_vendas = lojas[i].Preço.sum().round(2)
    vendas_geral = loja['Preço'].sum() + loja2['Preço'] .sum() + loja3['Preço'].sum() + loja4['Preço'] .sum()
    faturamento_total.append([f'Loja 0{i + 1}', total_de_vendas, (total_de_vendas * 100 / vendas_geral).round(1)])

faturamento_total = pd.DataFrame(faturamento_total)
faturamento_total.columns = ['Lojas', 'Total em R$', 'Percentual (%)']

print('------------------------------------')
print("\033[1mVENDAS POR LOJA COM OS RESPECTIVOS \nPERCENTUAIS SOBRE FATURAMENTO TOTAL\nDAS 4 LOJAS:\033[0m")
print('------------------------------------')
faturamento_total
# Out:
# ------------------------------------
# VENDAS POR LOJA COM OS RESPECTIVOS
# PERCENTUAIS SOBRE FATURAMENTO TOTAL
# DAS 4 LOJAS:
# ------------------------------------
#      Lojas  Total em R$  Percentual (%)
# 0  Loja 01   1534509.12            26.1
# 1  Loja 02   1488459.06            25.4
# 2  Loja 03   1464025.03            24.9
# 3  Loja 04   1384497.58            23.6

# %%
estilo_faturamento = faturamento_total.style
estilo_faturamento
# Out:
# <style type="text/css">
# </style>
# <table id="T_57e99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57e99_level0_col0" class="col_heading level0 col0" >Lojas</th>
#       <th id="T_57e99_level0_col1" class="col_heading level0 col1" >Total em R$</th>
#       <th id="T_57e99_level0_col2" class="col_heading level0 col2" >Percentual (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57e99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57e99_row0_col0" class="data row0 col0" >Loja 01</td>
#       <td id="T_57e99_row0_col1" class="data row0 col1" >1534509.120000</td>
#       <td id="T_57e99_row0_col2" class="data row0 col2" >26.100000</td>
#     </tr>
#     <tr>
#       <th id="T_57e99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57e99_row1_col0" class="data row1 col0" >Loja 02</td>
#       <td id="T_57e99_row1_col1" class="data row1 col1" >1488459.060000</td>
#       <td id="T_57e99_row1_col2" class="data row1 col2" >25.400000</td>
#     </tr>
#     <tr>
#       <th id="T_57e99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57e99_row2_col0" class="data row2 col0" >Loja 03</td>
#       <td id="T_57e99_row2_col1" class="data row2 col1" >1464025.030000</td>
#       <td id="T_57e99_row2_col2" class="data row2 col2" >24.900000</td>
#     </tr>
#     <tr>
#       <th id="T_57e99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57e99_row3_col0" class="data row3 col0" >Loja 04</td>
#       <td id="T_57e99_row3_col1" class="data row3 col1" >1384497.580000</td>
#       <td id="T_57e99_row3_col2" class="data row3 col2" >23.600000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_faturamento.format({'Total em R$':'R$ {:,.2f}','Percentual (%)' : '{:.1f}'}).background_gradient(cmap='Greens')
estilo_faturamento
# Out:
# <style type="text/css">
# #T_57e99_row0_col1, #T_57e99_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_57e99_row1_col1 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_57e99_row1_col2 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_57e99_row2_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_57e99_row2_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_57e99_row3_col1, #T_57e99_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_57e99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57e99_level0_col0" class="col_heading level0 col0" >Lojas</th>
#       <th id="T_57e99_level0_col1" class="col_heading level0 col1" >Total em R$</th>
#       <th id="T_57e99_level0_col2" class="col_heading level0 col2" >Percentual (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57e99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57e99_row0_col0" class="data row0 col0" >Loja 01</td>
#       <td id="T_57e99_row0_col1" class="data row0 col1" >R$ 1,534,509.12</td>
#       <td id="T_57e99_row0_col2" class="data row0 col2" >26.1</td>
#     </tr>
#     <tr>
#       <th id="T_57e99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57e99_row1_col0" class="data row1 col0" >Loja 02</td>
#       <td id="T_57e99_row1_col1" class="data row1 col1" >R$ 1,488,459.06</td>
#       <td id="T_57e99_row1_col2" class="data row1 col2" >25.4</td>
#     </tr>
#     <tr>
#       <th id="T_57e99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57e99_row2_col0" class="data row2 col0" >Loja 03</td>
#       <td id="T_57e99_row2_col1" class="data row2 col1" >R$ 1,464,025.03</td>
#       <td id="T_57e99_row2_col2" class="data row2 col2" >24.9</td>
#     </tr>
#     <tr>
#       <th id="T_57e99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57e99_row3_col0" class="data row3 col0" >Loja 04</td>
#       <td id="T_57e99_row3_col1" class="data row3 col1" >R$ 1,384,497.58</td>
#       <td id="T_57e99_row3_col2" class="data row3 col2" >23.6</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt


# Plote o gráfico de pizza
serie_pizza = faturamento_total.set_index('Lojas')['Total em R$']

plt.figure(figsize=(12, 4)) # Define o tamanho da figura
explode = (0, 0, 0, 0.1)
serie_pizza.plot(kind='pie', fontsize = 12, autopct='%1.1f%%',
                 shadow=True, explode = explode, startangle=90)

plt.title('Percentual de Vendas X Faturamento Total', fontsize = 18)
plt.ylabel('') # Remove o rótulo do , eixo Y
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
import pandas as pd
from IPython.display import display, HTML

p = 'Produto'
p1 ='Qtdes'
p2 = 'Preço'
p3 = 'Categoria do Produto'

lista_vendas = []

for i in range(len(lojas)):
    vendas = lojas[i].groupby(p3)[[p]].count().join(lojas[i].groupby(p3)[[p2]].sum()).sort_values(p)
    vendas = vendas.rename(columns={p : p1, p2 : f'Loja {i + 1} (R$)'})
    lista_vendas.append(vendas)

# 1. Converter cada DataFrame para string HTML
html_loja = lista_vendas[0].to_html()
html_loja2 = lista_vendas[1].to_html()
html_loja3 = lista_vendas[2].to_html()
html_loja4 = lista_vendas[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.

combined_html = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 01:</h3>
        {html_loja}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 02:</h3>
        {html_loja2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Vendas por Categoria da Loja 03:</h3>
        {html_loja3}
    </div>
    <div style="display: inline-block;">
        <h3>Vendas por Categoria da Loja 04:</h3>
        {html_loja4}
    </div>
</div>
"""
pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>171</td>
#       <td>16931.48</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>173</td>
#       <td>11713.92</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>182</td>
#       <td>121731.69</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>284</td>
#       <td>52387.55</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>312</td>
#       <td>484913.36</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>324</td>
#       <td>23993.78</td>
#     </tr>
#     <tr>
#       <th>eletronicos</th>
#       <td>448</td>
#       <td>572659.23</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>465</td>
#       <td>250178.11</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 02:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 2 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>181</td>
#       <td>19662.86</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>197</td>
#       <td>13454.35</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>224</td>
#       <td>139987.03</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>275</td>
#       <td>46326.09</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>305</td>
#       <td>464758.13</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>313</td>
#       <td>21262.21</td>
#     </tr>
#     <tr>
#       <th>eletronicos</th>
#       <td>422</td>
#       <td>547773.71</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>442</td>
#       <td>235234.68</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Vendas por Categoria da Loja 03:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 3 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>177</td>
#       <td>20080.21</td>
#     </tr>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>177</td>
#       <td>103174.45</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>185</td>
#       <td>12664.70</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>277</td>
#       <td>47456.10</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>278</td>
#       <td>438984.89</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>315</td>
#       <td>25869.20</td>
#     </tr>
#     <tr>
#       <th>eletronicos</th>
#       <td>451</td>
#       <td>547699.92</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>499</td>
#       <td>268095.56</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block;">
#         <h3>Vendas por Categoria da Loja 04:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Qtdes</th>
#       <th>Loja 4 (R$)</th>
#     </tr>
#     <tr>
#       <th>Categoria do Produto</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>instrumentos musicais</th>
#       <td>170</td>
#       <td>100136.50</td>
#     </tr>
#     <tr>
#       <th>livros</th>
#       <td>187</td>
#       <td>12427.77</td>
#     </tr>
#     <tr>
#       <th>utilidades domesticas</th>
#       <td>201</td>
#       <td>20098.83</td>
#     </tr>
#     <tr>
#       <th>eletrodomesticos</th>
#       <td>254</td>
#       <td>377680.65</td>
#     </tr>
#     <tr>
#       <th>esporte e lazer</th>
#       <td>277</td>
#       <td>44465.65</td>
#     </tr>
#     <tr>
#       <th>brinquedos</th>
#       <td>338</td>
#       <td>27015.67</td>
#     </tr>
#     <tr>
#       <th>eletronicos</th>
#       <td>451</td>
#       <td>545966.86</td>
#     </tr>
#     <tr>
#       <th>moveis</th>
#       <td>480</td>
#       <td>256705.65</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# </div>

# %%
estilo_categoria = lista_vendas[0].style
estilo_categoria
# Out:
# <style type="text/css">
# </style>
# <table id="T_08758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08758_level0_col0" class="col_heading level0 col0" >Qtdes</th>
#       <th id="T_08758_level0_col1" class="col_heading level0 col1" >Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria do Produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08758_level0_row0" class="row_heading level0 row0" >utilidades domesticas</th>
#       <td id="T_08758_row0_col0" class="data row0 col0" >171</td>
#       <td id="T_08758_row0_col1" class="data row0 col1" >16931.480000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row1" class="row_heading level0 row1" >livros</th>
#       <td id="T_08758_row1_col0" class="data row1 col0" >173</td>
#       <td id="T_08758_row1_col1" class="data row1 col1" >11713.920000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row2" class="row_heading level0 row2" >instrumentos musicais</th>
#       <td id="T_08758_row2_col0" class="data row2 col0" >182</td>
#       <td id="T_08758_row2_col1" class="data row2 col1" >121731.690000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row3" class="row_heading level0 row3" >esporte e lazer</th>
#       <td id="T_08758_row3_col0" class="data row3 col0" >284</td>
#       <td id="T_08758_row3_col1" class="data row3 col1" >52387.550000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row4" class="row_heading level0 row4" >eletrodomesticos</th>
#       <td id="T_08758_row4_col0" class="data row4 col0" >312</td>
#       <td id="T_08758_row4_col1" class="data row4 col1" >484913.360000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row5" class="row_heading level0 row5" >brinquedos</th>
#       <td id="T_08758_row5_col0" class="data row5 col0" >324</td>
#       <td id="T_08758_row5_col1" class="data row5 col1" >23993.780000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row6" class="row_heading level0 row6" >eletronicos</th>
#       <td id="T_08758_row6_col0" class="data row6 col0" >448</td>
#       <td id="T_08758_row6_col1" class="data row6 col1" >572659.230000</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row7" class="row_heading level0 row7" >moveis</th>
#       <td id="T_08758_row7_col0" class="data row7 col0" >465</td>
#       <td id="T_08758_row7_col1" class="data row7 col1" >250178.110000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_categoria.format({'Loja 1 (R$)':'R$ {:,.2f}'}).background_gradient(cmap='Greens')
estilo_categoria
# Out:
# <style type="text/css">
# #T_08758_row0_col0, #T_08758_row1_col1 {
#   background-color: #0d0887;
#   color: #f1f1f1;
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #0b0000;
#   color: #f1f1f1;
#   background-color: #f7fbff;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_08758_row0_col1 {
#   background-color: #130789;
#   color: #f1f1f1;
#   background-color: #f6fcf4;
#   color: #000000;
#   background-color: #100000;
#   color: #f1f1f1;
#   background-color: #f5fafe;
#   color: #000000;
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_08758_row1_col0 {
#   background-color: #100788;
#   color: #f1f1f1;
#   background-color: #f6fcf4;
#   color: #000000;
#   background-color: #0d0000;
#   color: #f1f1f1;
#   background-color: #f6faff;
#   color: #000000;
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_08758_row2_col0 {
#   background-color: #240691;
#   color: #f1f1f1;
#   background-color: #f2faef;
#   color: #000000;
#   background-color: #220000;
#   color: #f1f1f1;
#   background-color: #f0f6fd;
#   color: #000000;
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_08758_row2_col1 {
#   background-color: #6900a8;
#   color: #f1f1f1;
#   background-color: #d4eece;
#   color: #000000;
#   background-color: #8e0000;
#   color: #f1f1f1;
#   background-color: #d0e2f2;
#   color: #000000;
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_08758_row3_col0 {
#   background-color: #ac2694;
#   color: #f1f1f1;
#   background-color: #9ed798;
#   color: #000000;
#   background-color: #ff0d00;
#   color: #f1f1f1;
#   background-color: #9ac8e0;
#   color: #000000;
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_08758_row3_col1 {
#   background-color: #350498;
#   color: #f1f1f1;
#   background-color: #edf8e9;
#   color: #000000;
#   background-color: #3a0000;
#   color: #f1f1f1;
#   background-color: #e9f2fa;
#   color: #000000;
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_08758_row4_col0 {
#   background-color: #c6417d;
#   color: #f1f1f1;
#   background-color: #7cc87c;
#   color: #000000;
#   background-color: #ff4c00;
#   color: #f1f1f1;
#   background-color: #74b3d8;
#   color: #000000;
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_08758_row4_col1 {
#   background-color: #feb72d;
#   color: #000000;
#   background-color: #097532;
#   color: #f1f1f1;
#   background-color: #ffff61;
#   color: #000000;
#   background-color: #0e59a2;
#   color: #f1f1f1;
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_08758_row5_col0 {
#   background-color: #d04d73;
#   color: #f1f1f1;
#   background-color: #6bc072;
#   color: #000000;
#   background-color: #ff6900;
#   color: #f1f1f1;
#   background-color: #64a9d3;
#   color: #f1f1f1;
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_08758_row5_col1 {
#   background-color: #1b068d;
#   color: #f1f1f1;
#   background-color: #f4fbf2;
#   color: #000000;
#   background-color: #180000;
#   color: #f1f1f1;
#   background-color: #f3f8fe;
#   color: #000000;
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_08758_row6_col0 {
#   background-color: #f8e125;
#   color: #000000;
#   background-color: #005622;
#   color: #f1f1f1;
#   background-color: #ffffc8;
#   color: #000000;
#   background-color: #083e81;
#   color: #f1f1f1;
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_08758_row6_col1, #T_08758_row7_col0 {
#   background-color: #f0f921;
#   color: #000000;
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #ffffff;
#   color: #000000;
#   background-color: #08306b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_08758_row7_col1 {
#   background-color: #b7318a;
#   color: #f1f1f1;
#   background-color: #90d18d;
#   color: #000000;
#   background-color: #ff2700;
#   color: #f1f1f1;
#   background-color: #8abfdd;
#   color: #000000;
#   background-color: #90d18d;
#   color: #000000;
# }
# </style>
# <table id="T_08758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08758_level0_col0" class="col_heading level0 col0" >Qtdes</th>
#       <th id="T_08758_level0_col1" class="col_heading level0 col1" >Loja 1 (R$)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria do Produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08758_level0_row0" class="row_heading level0 row0" >utilidades domesticas</th>
#       <td id="T_08758_row0_col0" class="data row0 col0" >171</td>
#       <td id="T_08758_row0_col1" class="data row0 col1" >R$ 16,931.48</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row1" class="row_heading level0 row1" >livros</th>
#       <td id="T_08758_row1_col0" class="data row1 col0" >173</td>
#       <td id="T_08758_row1_col1" class="data row1 col1" >R$ 11,713.92</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row2" class="row_heading level0 row2" >instrumentos musicais</th>
#       <td id="T_08758_row2_col0" class="data row2 col0" >182</td>
#       <td id="T_08758_row2_col1" class="data row2 col1" >R$ 121,731.69</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row3" class="row_heading level0 row3" >esporte e lazer</th>
#       <td id="T_08758_row3_col0" class="data row3 col0" >284</td>
#       <td id="T_08758_row3_col1" class="data row3 col1" >R$ 52,387.55</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row4" class="row_heading level0 row4" >eletrodomesticos</th>
#       <td id="T_08758_row4_col0" class="data row4 col0" >312</td>
#       <td id="T_08758_row4_col1" class="data row4 col1" >R$ 484,913.36</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row5" class="row_heading level0 row5" >brinquedos</th>
#       <td id="T_08758_row5_col0" class="data row5 col0" >324</td>
#       <td id="T_08758_row5_col1" class="data row5 col1" >R$ 23,993.78</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row6" class="row_heading level0 row6" >eletronicos</th>
#       <td id="T_08758_row6_col0" class="data row6 col0" >448</td>
#       <td id="T_08758_row6_col1" class="data row6 col1" >R$ 572,659.23</td>
#     </tr>
#     <tr>
#       <th id="T_08758_level0_row7" class="row_heading level0 row7" >moveis</th>
#       <td id="T_08758_row7_col0" class="data row7 col0" >465</td>
#       <td id="T_08758_row7_col1" class="data row7 col1" >R$ 250,178.11</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np

cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# Criando a figura
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Ajustando o espaçamento
fig.subplots_adjust(hspace=0.5, wspace=0.3)

# Adicionando um título geral para os subplots
fig.suptitle('Vendas por Categoria de todas as lojas')

# Subplots

# 3. Iterar e plotar em cada subplot usando o loop for
# axes.flatten() transforma a matriz 2x2 em uma lista 1D para facilitar o loop
for i, ax in enumerate(axs.flatten()): # 'i' é o índice (0, 1, 2, 3)
    ax.barh(lista_vendas[i].index, lista_vendas[i][p1], color=cores, height = 0.75)
    ax.set_title(f'Loja 0{i + 1}')
    ax.set_xlabel('Quantidades', fontsize=12)
    ax.set_ylabel('')
    ax.set_frame_on(False)   # Retirando o Frame (retângulo que encobre os gráficos)
    ax.set_xticklabels([])   # Opção A: Definir os rótulos como uma lista vazia
    ax.tick_params(axis='both', which='both', length=0)   # Removendo todos os ticks dos eixos X e Y
    ax.yaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_major_locator(plt.MultipleLocator(50))

    # Loop para adicionar o valor máximo de cada barra
    for j, v in enumerate(lista_vendas[i][p1]):
        ax.text(v + 5, j, str(v), color='black',
                fontsize=9, ha='left', va='center')
                
# 3. Ajustar layout para evitar sobreposição (opcional)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import IPython.display

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado = pd.concat([lista_vendas[0], lista_vendas[1], lista_vendas[2], lista_vendas[3]], axis=1)

print('---------------------')
print("\033[1mVENDAS POR CATEGORIA:\033[0m")
print('---------------------')

display(df_combinado)
# Out:
# ---------------------
# VENDAS POR CATEGORIA:
# ---------------------
#                        Qtdes  Loja 1 (R$)  Qtdes  Loja 2 (R$)  Qtdes  \
# Categoria do Produto
# utilidades domesticas    171     16931.48    181     19662.86    177
# livros                   173     11713.92    197     13454.35    185
# instrumentos musicais    182    121731.69    224    139987.03    177
# esporte e lazer          284     52387.55    275     46326.09    277
# eletrodomesticos         312    484913.36    305    464758.13    278
# brinquedos               324     23993.78    313     21262.21    315
# eletronicos              448    572659.23    422    547773.71    451
# moveis                   465    250178.11    442    235234.68    499
#
#                        Loja 3 (R$)  Qtdes  Loja 4 (R$)
# Categoria do Produto
# utilidades domesticas     20080.21    201     20098.83
# livros                    12664.70    187     12427.77
# instrumentos musicais    103174.45    170    100136.50
# esporte e lazer           47456.10    277     44465.65
# eletrodomesticos         438984.89    254    377680.65
# brinquedos                25869.20    338     27015.67
# eletronicos              547699.92    451    545966.86
# moveis                   268095.56    480    256705.65

# %%
import pandas as pd
import IPython.display

categorias_juntas = []

for i in range(len(lojas)):
    vendas = lojas[i].groupby(p3)[[p]].count().join(lojas[i].groupby(p3)[[p2]].sum()).round(2).sort_values(p)
    vendas = vendas.rename(columns={p : p1, p2 : f'Loja 0{i + 1} (R$)'}).join((lojas[i].groupby(p3)[[p2]].sum() * 100 / lojas[i].Preço.sum()).round(1))
    vendas = vendas.rename(columns={p2 : '% Vendas'})
    categorias_juntas.append(vendas)

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado_categoria = pd.concat([categorias_juntas[0], categorias_juntas[1], categorias_juntas[2], categorias_juntas[3]], axis=1)

print('-------------------------------------')
print("\033[1mVENDAS POR CATEGORIA COM PERCENTUAIS:\033[0m")
print('-------------------------------------')

display(df_combinado_categoria)
# Out:
# -------------------------------------
# VENDAS POR CATEGORIA COM PERCENTUAIS:
# -------------------------------------
#                        Qtdes  Loja 01 (R$)  % Vendas  Qtdes  Loja 02 (R$)  \
# Categoria do Produto
# utilidades domesticas    171      16931.48       1.1    181      19662.86
# livros                   173      11713.92       0.8    197      13454.35
# instrumentos musicais    182     121731.69       7.9    224     139987.03
# esporte e lazer          284      52387.55       3.4    275      46326.09
# eletrodomesticos         312     484913.36      31.6    305     464758.13
# brinquedos               324      23993.78       1.6    313      21262.21
# eletronicos              448     572659.23      37.3    422     547773.71
# moveis                   465     250178.11      16.3    442     235234.68
#
#                        % Vendas  Qtdes  Loja 03 (R$)  % Vendas  Qtdes  \
# Categoria do Produto
# utilidades domesticas       1.3    177      20080.21       1.4    201
# livros                      0.9    185      12664.70       0.9    187
# instrumentos musicais       9.4    177     103174.45       7.0    170
# esporte e lazer             3.1    277      47456.10       3.2    277
# eletrodomesticos           31.2    278     438984.89      30.0    254
# brinquedos                  1.4    315      25869.20       1.8    338
# eletronicos                36.8    451     547699.92      37.4    451
# moveis                     15.8    499     268095.56      18.3    480
#
#                        Loja 04 (R$)  % Vendas
# Categoria do Produto
# utilidades domesticas      20098.83       1.5
# livros                     12427.77       0.9
# instrumentos musicais     100136.50       7.2
# esporte e lazer            44465.65       3.2
# eletrodomesticos          377680.65      27.3
# brinquedos                 27015.67       2.0
# eletronicos               545966.86      39.4
# moveis                    256705.65      18.5

# %%
import numpy as np

p = 'Produto'
p1 ='Qtdes'
p2 = 'Preço'
p3 = 'Categoria do Produto'

cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# Criando a figura
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Ajustando o espaçamento
fig.subplots_adjust(hspace=0.4, wspace=0.5)

# Adicionando um título geral para os subplots
fig.suptitle('Vendas por Categoria de todas as lojas', fontsize = 18)

# Subplots

# 3. Iterar e plotar em cada subplot usando o loop for
# axes.flatten() transforma a matriz 2x2 em uma lista 1D para facilitar o loop
for i, ax in enumerate(axs.flatten()): # 'i' é o índice (0, 1, 2, 3)
    ax.barh(categorias_juntas[i].index, categorias_juntas[i][p1], color=cores, height = 0.8)
    ax.set_title(f'Loja 0{i + 1}')
    ax.set_xlabel('Quantidades', fontsize=12)
    ax.set_ylabel('')
    ax.set_frame_on(False)   # Retirando o Frame (retângulo que encobre os gráficos)
    ax.set_xticklabels([])   # Opção A: Definir os rótulos como uma lista vazia
    ax.tick_params(axis='both', which='both', length=0)   # Removendo todos os ticks dos eixos X e Y
    ax.yaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_tick_params(labelsize=9)
    ax.xaxis.set_major_locator(plt.MultipleLocator(50))

    # Loop para adicionar o valor máximo de cada barra
    for j, v in enumerate(categorias_juntas[i][p1]):
        ax.text(v + 5, j, str(v), color='black',
                fontsize=9, ha='left', va='center')
        
    for k, value in enumerate(categorias_juntas[i][p1]):
        # Posição x: valor da barra / 2 (para o centro horizontal)
        # Posição y: index da barra (posição vertical)
        # Texto: o dado extra da coluna 'Percentual (%)'
        ax.annotate(
            str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
            xy=(value / 2, k),
            ha='center', # Alinhamento horizontal: centro
            va='center', # Alinhamento vertical: centro
            color='white', # Cor do texto para contraste
            fontweight='bold',   # negrito
            fontsize=8
        )

# 3. Ajustar layout para evitar sobreposição (opcional)
#plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_15790/566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
# /tmp/ipykernel_15790/566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
# /tmp/ipykernel_15790/566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),
# /tmp/ipykernel_15790/566681011.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(f'R$ {categorias_juntas[i][f'Loja 0{i + 1} (R$)'][k]}'),

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

medias_avaliacoes_compras = []
avaliacoes_lojas  = []

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    medias_avaliacoes_compras.append(lojas[i]['Avaliação da compra'].mean().round(2))
    avaliacoes_lojas.append([f'Loja 0{i + 1}', medias_avaliacoes_compras[i]])

avaliacoes_lojas = pd.DataFrame(avaliacoes_lojas)
avaliacoes_lojas.columns = ['Lojas', 'Média das Avaliações']
avaliacoes_lojas.sort_values(by='Média das Avaliações', ascending=False, inplace = True)
avaliacoes_lojas = avaliacoes_lojas.reset_index(drop = True)
avaliacoes_lojas
# Out:
#      Lojas  Média das Avaliações
# 0  Loja 03                  4.05
# 1  Loja 02                  4.04
# 2  Loja 04                  4.00
# 3  Loja 01                  3.98

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 14})

# Dados de exemplo
valores = avaliacoes_lojas['Média das Avaliações']
rotulos = avaliacoes_lojas['Lojas']

# Função personalizada para formatar os rótulos
# pct é a porcentagem calculada automaticamente pelo matplotlib para cada fatia
def formatar_valor(pct, valores):
    total = sum(valores)
    # Calcula o valor absoluto correspondente à porcentagem
    val = float(pct * total / 100.0)
    # Retorna o valor formatado como string, sem o símbolo de porcentagem
    return '{v:.2f}'.format(v=val)

plt.figure(figsize=(8, 4))

explode = (0, 0, 0, 0.1)

# Criando o gráfico de pizza
plt.pie(valores, 
        labels=rotulos, 
        explode = explode, 
        autopct=lambda p: formatar_valor(p, valores), # Passa a função personalizada com os valores originais
        shadow=True, 
        startangle=90
        )

# Garante que o gráfico seja desenhado como um círculo perfeito
plt.axis('equal')

# Adiciona um título
plt.title('Médias das Avaliações de compras de todas as Lojas', fontsize = 18)

# Exibe o gráfico
plt.show()

# %%
import pandas as pd
import IPython.display

p4 = 'Avaliação da compra'

produtos_juntos = []

for i in range(len(lojas)):
    aval_produto = lojas[i].groupby(p)[[p4]].mean().round(2)
    aval_produto = aval_produto.rename(columns={p4 : f'Média das Avaliações na na Loja 0{i + 1}'})
    produtos_juntos.append(aval_produto)

# Concatena horizontalmente (axis=1) em um único DataFrame
df_combinado_produto = pd.concat([produtos_juntos[0], produtos_juntos[1], produtos_juntos[2], produtos_juntos[3]], axis=1)

print('-------------------------------------')
print("\033[1mVENDAS POR CATEGORIA COM PERCENTUAIS:\033[0m")
print('-------------------------------------')

display(df_combinado_produto)
# Out:
# -------------------------------------
# VENDAS POR CATEGORIA COM PERCENTUAIS:
# -------------------------------------
#                              Média das Avaliações na na Loja 01  \
# Produto
# Assistente virtual                                         4.08
# Bateria                                                    4.19
# Bicicleta                                                  3.94
# Blocos de montar                                           4.09
# Bola de basquete                                           3.87
# Bola de vôlei                                              4.07
# Boneca bebê                                                3.98
# Cadeira de escritório                                      3.85
# Cama box                                                   4.11
# Cama king                                                  3.77
# Carrinho controle remoto                                   4.13
# Celular ABXY                                               3.82
# Celular Plus X42                                           3.94
# Ciência de dados com python                                4.10
# Copo térmico                                               3.89
# Corda de pular                                             3.62
# Cubo mágico 8x8                                            4.07
# Cômoda                                                     3.80
# Dashboards com Power BI                                    3.95
# Dinossauro Rex                                             3.78
# Faqueiro                                                   4.23
# Fogão                                                      4.13
# Fone de ouvido                                             3.64
# Geladeira                                                  4.02
# Guarda roupas                                              3.95
# Guitarra                                                   4.09
# Headset                                                    3.97
# Impressora                                                 4.17
# Iniciando em programação                                   4.29
# Jogo de copos                                              3.29
# Jogo de panelas                                            3.58
# Jogo de tabuleiro                                          3.98
# Kit banquetas                                              4.11
# Lava louças                                                4.02
# Lavadora de roupas                                         4.13
# Mesa de centro                                             4.02
# Mesa de jantar                                             3.80
# Micro-ondas                                                3.98
# Mochila                                                    3.97
# Modelagem preditiva                                        3.65
# Pandeiro                                                   3.92
# Panela de pressão                                          3.77
# Poltrona                                                   4.07
# Secadora de roupas                                         3.95
# Smart TV                                                   4.00
# Smartwatch                                                 4.21
# Sofá retrátil                                              4.00
# TV Led UHD 4K                                              4.05
# Tablet ABXY                                                4.14
# Violão                                                     3.96
# Xadrez de madeira                                          4.43
#
#                              Média das Avaliações na na Loja 02  \
# Produto
# Assistente virtual                                         3.84
# Bateria                                                    4.03
# Bicicleta                                                  4.53
# Blocos de montar                                           4.28
# Bola de basquete                                           4.10
# Bola de vôlei                                              3.83
# Boneca bebê                                                3.71
# Cadeira de escritório                                      4.06
# Cama box                                                   4.09
# Cama king                                                  4.44
# Carrinho controle remoto                                   4.13
# Celular ABXY                                               4.05
# Celular Plus X42                                           3.80
# Ciência de dados com python                                3.84
# Copo térmico                                               3.66
# Corda de pular                                             4.04
# Cubo mágico 8x8                                            3.62
# Cômoda                                                     4.00
# Dashboards com Power BI                                    4.00
# Dinossauro Rex                                             4.33
# Faqueiro                                                   3.62
# Fogão                                                      4.00
# Fone de ouvido                                             3.84
# Geladeira                                                  4.22
# Guarda roupas                                              3.89
# Guitarra                                                   3.89
# Headset                                                    3.89
# Impressora                                                 4.44
# Iniciando em programação                                   4.00
# Jogo de copos                                              4.02
# Jogo de panelas                                            4.38
# Jogo de tabuleiro                                          3.97
# Kit banquetas                                              3.96
# Lava louças                                                4.11
# Lavadora de roupas                                         3.73
# Mesa de centro                                             4.11
# Mesa de jantar                                             4.24
# Micro-ondas                                                4.08
# Mochila                                                    4.27
# Modelagem preditiva                                        3.93
# Pandeiro                                                   4.19
# Panela de pressão                                          4.16
# Poltrona                                                   4.20
# Secadora de roupas                                         4.25
# Smart TV                                                   3.98
# Smartwatch                                                 3.89
# Sofá retrátil                                              4.05
# TV Led UHD 4K                                              4.09
# Tablet ABXY                                                4.02
# Violão                                                     4.00
# Xadrez de madeira                                          4.11
#
#                              Média das Avaliações na na Loja 03  \
# Produto
# Assistente virtual                                         3.69
# Bateria                                                    3.98
# Bicicleta                                                  3.77
# Blocos de montar                                           4.34
# Bola de basquete                                           4.00
# Bola de vôlei                                              3.73
# Boneca bebê                                                4.18
# Cadeira de escritório                                      3.89
# Cama box                                                   3.87
# Cama king                                                  4.04
# Carrinho controle remoto                                   4.19
# Celular ABXY                                               4.36
# Celular Plus X42                                           4.04
# Ciência de dados com python                                4.02
# Copo térmico                                               4.39
# Corda de pular                                             3.91
# Cubo mágico 8x8                                            4.18
# Cômoda                                                     4.25
# Dashboards com Power BI                                    4.35
# Dinossauro Rex                                             4.09
# Faqueiro                                                   3.87
# Fogão                                                      4.23
# Fone de ouvido                                             4.02
# Geladeira                                                  4.42
# Guarda roupas                                              4.14
# Guitarra                                                   4.08
# Headset                                                    3.79
# Impressora                                                 4.36
# Iniciando em programação                                   4.07
# Jogo de copos                                              4.03
# Jogo de panelas                                            4.11
# Jogo de tabuleiro                                          4.54
# Kit banquetas                                              4.21
# Lava louças                                                3.85
# Lavadora de roupas                                         3.93
# Mesa de centro                                             3.69
# Mesa de jantar                                             4.18
# Micro-ondas                                                3.50
# Mochila                                                    3.94
# Modelagem preditiva                                        3.83
# Pandeiro                                                   4.04
# Panela de pressão                                          4.23
# Poltrona                                                   4.32
# Secadora de roupas                                         3.98
# Smart TV                                                   3.85
# Smartwatch                                                 3.83
# Sofá retrátil                                              4.29
# TV Led UHD 4K                                              4.21
# Tablet ABXY                                                3.67
# Violão                                                     3.94
# Xadrez de madeira                                          3.85
#
#                              Média das Avaliações na na Loja 04
# Produto
# Assistente virtual                                         4.04
# Bateria                                                    4.33
# Bicicleta                                                  3.89
# Blocos de montar                                           3.81
# Bola de basquete                                           3.88
# Bola de vôlei                                              4.29
# Boneca bebê                                                4.08
# Cadeira de escritório                                      4.03
# Cama box                                                   3.98
# Cama king                                                  3.86
# Carrinho controle remoto                                   3.95
# Celular ABXY                                               3.90
# Celular Plus X42                                           4.08
# Ciência de dados com python                                3.84
# Copo térmico                                               4.15
# Corda de pular                                             4.28
# Cubo mágico 8x8                                            3.85
# Cômoda                                                     4.15
# Dashboards com Power BI                                    4.02
# Dinossauro Rex                                             4.00
# Faqueiro                                                   3.98
# Fogão                                                      3.83
# Fone de ouvido                                             4.32
# Geladeira                                                  3.95
# Guarda roupas                                              4.24
# Guitarra                                                   3.79
# Headset                                                    3.98
# Impressora                                                 4.06
# Iniciando em programação                                   4.26
# Jogo de copos                                              4.04
# Jogo de panelas                                            3.94
# Jogo de tabuleiro                                          4.25
# Kit banquetas                                              4.12
# Lava louças                                                3.86
# Lavadora de roupas                                         4.00
# Mesa de centro                                             3.75
# Mesa de jantar                                             3.96
# Micro-ondas                                                4.10
# Mochila                                                    3.84
# Modelagem preditiva                                        4.04
# Pandeiro                                                   3.77
# Panela de pressão                                          4.09
# Poltrona                                                   4.11
# Secadora de roupas                                         3.82
# Smart TV                                                   4.04
# Smartwatch                                                 3.97
# Sofá retrátil                                              3.87
# TV Led UHD 4K                                              3.58
# Tablet ABXY                                                4.02
# Violão                                                     3.68
# Xadrez de madeira                                          4.00

# %%
import pandas as pd
from IPython.display import display, HTML

lista_vendas_aval = []

for i in range(len(lojas)):
    aval_1 = lojas[i].groupby(p)[[p4]].mean().round(2).sort_values(p4, ascending = False)
    aval_1 = aval_1.rename(columns = {p4 : 'Média das Avaliações'})
    aval_1 = pd.concat([aval_1.head(5), aval_1.tail(5)])
    lista_vendas_aval.append(aval_1)

# 1. Converter cada DataFrame para string HTML
html_loja_1 = lista_vendas_aval[0].to_html()
html_loja_2 = lista_vendas_aval[1].to_html()
html_loja_3 = lista_vendas_aval[2].to_html()
html_loja_4 = lista_vendas_aval[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.
combined_html_2 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Avaliações das compras da Loja 01:</h3>
        {html_loja_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Avaliações da compras da Loja 02:</h3>
        {html_loja_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Avaliações da compras da Loja 03:</h3>
        {html_loja_3}
    </div>
    <div style="display: inline-block;">
        <h3>Avaliações da compras da Loja 04:</h3>
        {html_loja_4}
    </div>
</div>
"""

pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_2))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Avaliações das compras da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Média das Avaliações</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>4.43</td>
#     </tr>
#     <tr>
#       <th>Iniciando em programação</th>
#       <td>4.29</td>
#     </tr>
#     <tr>
#       <th>Faqueiro</th>
#       <td>4.23</td>
#     </tr>
#     <tr>
#       <th>Smartwatch</th>
#       <td>4.21</td>
#     </tr>
#     <tr>
#       <th>Bateria</th>
#       <td>4.19</td>
#     </tr>
#     <tr>
#       <th>Modelagem preditiva</th>
#       <td>3.65</td>
#     </tr>
#     <tr>
#       <th>Fone de ouvido</th>
#       <td>3.64</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>3.62</td>
#     </tr>
#     <tr>
#       <th>Jogo de panelas</th>
#       <td>3.58</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>3.29</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Avaliações da compras da Loja 02:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Média das Avaliações</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bicicleta</th>
#       <td>4.53</td>
#     </tr>
#     <tr>
#       <th>Cama king</th>
#       <td>4.44</td>
#     </tr>
#     <tr>
#       <th>Impressora</th>
#       <td>4.44</td>
#     </tr>
#     <tr>
#       <th>Jogo de panelas</th>
#       <td>4.38</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>4.33</td>
#     </tr>
#     <tr>
#       <th>Lavadora de roupas</th>
#       <td>3.73</td>
#     </tr>
#     <tr>
#       <th>Boneca bebê</th>
#       <td>3.71</td>
#     </tr>
#     <tr>
#       <th>Copo térmico</th>
#       <td>3.66</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>
#       <td>3.62</td>
#     </tr>
#     <tr>
#       <th>Faqueiro</th>
#       <td>3.62</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Avaliações da compras da Loja 03:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Média das Avaliações</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Jogo de tabuleiro</th>
#       <td>4.54</td>
#     </tr>
#     <tr>
#       <th>Geladeira</th>
#       <td>4.42</td>
#     </tr>
#     <tr>
#       <th>Copo térmico</th>
#       <td>4.39</td>
#     </tr>
#     <tr>
#       <th>Celular ABXY</th>
#       <td>4.36</td>
#     </tr>
#     <tr>
#       <th>Impressora</th>
#       <td>4.36</td>
#     </tr>
#     <tr>
#       <th>Bola de vôlei</th>
#       <td>3.73</td>
#     </tr>
#     <tr>
#       <th>Assistente virtual</th>
#       <td>3.69</td>
#     </tr>
#     <tr>
#       <th>Mesa de centro</th>
#       <td>3.69</td>
#     </tr>
#     <tr>
#       <th>Tablet ABXY</th>
#       <td>3.67</td>
#     </tr>
#     <tr>
#       <th>Micro-ondas</th>
#       <td>3.50</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block;">
#         <h3>Avaliações da compras da Loja 04:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Média das Avaliações</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bateria</th>
#       <td>4.33</td>
#     </tr>
#     <tr>
#       <th>Fone de ouvido</th>
#       <td>4.32</td>
#     </tr>
#     <tr>
#       <th>Bola de vôlei</th>
#       <td>4.29</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>4.28</td>
#     </tr>
#     <tr>
#       <th>Iniciando em programação</th>
#       <td>4.26</td>
#     </tr>
#     <tr>
#       <th>Guitarra</th>
#       <td>3.79</td>
#     </tr>
#     <tr>
#       <th>Pandeiro</th>
#       <td>3.77</td>
#     </tr>
#     <tr>
#       <th>Mesa de centro</th>
#       <td>3.75</td>
#     </tr>
#     <tr>
#       <th>Violão</th>
#       <td>3.68</td>
#     </tr>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>3.58</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# </div>

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
import pandas as pd
from IPython.display import display, HTML

preco_produtos = []
top_produtos = []

for i in range(len(lojas)):
    preco_1 = lojas[i].groupby(p)[[p2]].sum().round(2).sort_values(p2, ascending = False)
    preco_1 = preco_1.rename(columns = {p2 : 'Venda Total em (R$)'})
    preco_produtos.append(preco_1)
    produto_1 = pd.concat([preco_1.head(5), preco_1.tail(5)])
    top_produtos.append(produto_1)

# 1. Converter cada DataFrame para string HTML
html_preco_1 = preco_produtos[0].to_html()
html_preco_2 = preco_produtos[1].to_html()
html_preco_3 = preco_produtos[2].to_html()
html_preco_4 = preco_produtos[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.

combined_html_3 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 01:</h3>
        {html_preco_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 02:</h3>
        {html_preco_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Produtos vendidos na Loja 03:</h3>
        {html_preco_3}
    </div>
    <div style="display: inline-block;">
        <h3>Produtos vendidos na Loja 04:</h3>
        {html_preco_4}
    </div>
</div>
"""
pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_3))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Produtos vendidos na Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Venda Total em (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>189534.28</td>
#     </tr>
#     <tr>
#       <th>Geladeira</th>
#       <td>149524.28</td>
#     </tr>
#     <tr>
#       <th>Celular Plus X42</th>
#       <td>130536.40</td>
#     </tr>
#     <tr>
#       <th>Smart TV</th>
#       <td>89936.15</td>
#     </tr>
#     <tr>
#       <th>Lavadora de roupas</th>
#       <td>87711.30</td>
#     </tr>
#     <tr>
#       <th>Lava louças</th>
#       <td>82739.86</td>
#     </tr>
#     <tr>
#       <th>Secadora de roupas</th>
#       <td>78749.73</td>
#     </tr>
#     <tr>
#       <th>Tablet ABXY</th>
#       <td>63520.11</td>
#     </tr>
#     <tr>
#       <th>Bateria</th>
#       <td>50258.34</td>
#     </tr>
#     <tr>
#       <th>Guitarra</th>
#       <td>49722.88</td>
#     </tr>
#     <tr>
#       <th>Micro-ondas</th>
#       <td>46348.89</td>
#     </tr>
#     <tr>
#       <th>Celular ABXY</th>
#       <td>43534.47</td>
#     </tr>
#     <tr>
#       <th>Sofá retrátil</th>
#       <td>41839.25</td>
#     </tr>
#     <tr>
#       <th>Cama king</th>
#       <td>41569.04</td>
#     </tr>
#     <tr>
#       <th>Fogão</th>
#       <td>39839.30</td>
#     </tr>
#     <tr>
#       <th>Guarda roupas</th>
#       <td>39282.78</td>
#     </tr>
#     <tr>
#       <th>Bicicleta</th>
#       <td>36592.38</td>
#     </tr>
#     <tr>
#       <th>Cama box</th>
#       <td>29459.35</td>
#     </tr>
#     <tr>
#       <th>Cadeira de escritório</th>
#       <td>23556.36</td>
#     </tr>
#     <tr>
#       <th>Impressora</th>
#       <td>21884.23</td>
#     </tr>
#     <tr>
#       <th>Cômoda</th>
#       <td>20905.92</td>
#     </tr>
#     <tr>
#       <th>Violão</th>
#       <td>18765.28</td>
#     </tr>
#     <tr>
#       <th>Kit banquetas</th>
#       <td>16188.25</td>
#     </tr>
#     <tr>
#       <th>Mesa de jantar</th>
#       <td>14042.39</td>
#     </tr>
#     <tr>
#       <th>Poltrona</th>
#       <td>13172.23</td>
#     </tr>
#     <tr>
#       <th>Assistente virtual</th>
#       <td>10744.05</td>
#     </tr>
#     <tr>
#       <th>Mesa de centro</th>
#       <td>10162.54</td>
#     </tr>
#     <tr>
#       <th>Jogo de tabuleiro</th>
#       <td>10152.50</td>
#     </tr>
#     <tr>
#       <th>Smartwatch</th>
#       <td>9936.51</td>
#     </tr>
#     <tr>
#       <th>Jogo de panelas</th>
#       <td>8410.44</td>
#     </tr>
#     <tr>
#       <th>Fone de ouvido</th>
#       <td>6725.32</td>
#     </tr>
#     <tr>
#       <th>Headset</th>
#       <td>6307.71</td>
#     </tr>
#     <tr>
#       <th>Mochila</th>
#       <td>5156.50</td>
#     </tr>
#     <tr>
#       <th>Carrinho controle remoto</th>
#       <td>5015.28</td>
#     </tr>
#     <tr>
#       <th>Modelagem preditiva</th>
#       <td>4229.85</td>
#     </tr>
#     <tr>
#       <th>Bola de basquete</th>
#       <td>3666.88</td>
#     </tr>
#     <tr>
#       <th>Panela de pressão</th>
#       <td>3505.71</td>
#     </tr>
#     <tr>
#       <th>Copo térmico</th>
#       <td>3284.68</td>
#     </tr>
#     <tr>
#       <th>Faqueiro</th>
#       <td>3203.18</td>
#     </tr>
#     <tr>
#       <th>Pandeiro</th>
#       <td>2985.19</td>
#     </tr>
#     <tr>
#       <th>Bola de vôlei</th>
#       <td>2816.22</td>
#     </tr>
#     <tr>
#       <th>Iniciando em programação</th>
#       <td>2791.03</td>
#     </tr>
#     <tr>
#       <th>Ciência de dados com python</th>
#       <td>2752.18</td>
#     </tr>
#     <tr>
#       <th>Boneca bebê</th>
#       <td>2583.17</td>
#     </tr>
#     <tr>
#       <th>Blocos de montar</th>
#       <td>2487.74</td>
#     </tr>
#     <tr>
#       <th>Dashboards com Power BI</th>
#       <td>1940.86</td>
#     </tr>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>1907.42</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>1812.15</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>
#       <td>929.27</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>918.40</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>870.89</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Produtos vendidos na Loja 02:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Venda Total em (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Celular Plus X42</th>
#       <td>150967.83</td>
#     </tr>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>137833.06</td>
#     </tr>
#     <tr>
#       <th>Geladeira</th>
#       <td>130176.48</td>
#     </tr>
#     <tr>
#       <th>Lavadora de roupas</th>
#       <td>89016.81</td>
#     </tr>
#     <tr>
#       <th>Smart TV</th>
#       <td>81522.94</td>
#     </tr>
#     <tr>
#       <th>Secadora de roupas</th>
#       <td>78820.31</td>
#     </tr>
#     <tr>
#       <th>Lava louças</th>
#       <td>78357.00</td>
#     </tr>
#     <tr>
#       <th>Tablet ABXY</th>
#       <td>74945.97</td>
#     </tr>
#     <tr>
#       <th>Bateria</th>
#       <td>61566.87</td>
#     </tr>
#     <tr>
#       <th>Celular ABXY</th>
#       <td>55558.43</td>
#     </tr>
#     <tr>
#       <th>Guitarra</th>
#       <td>48589.03</td>
#     </tr>
#     <tr>
#       <th>Micro-ondas</th>
#       <td>48256.37</td>
#     </tr>
#     <tr>
#       <th>Fogão</th>
#       <td>40131.16</td>
#     </tr>
#     <tr>
#       <th>Sofá retrátil</th>
#       <td>39318.68</td>
#     </tr>
#     <tr>
#       <th>Cama king</th>
#       <td>37618.26</td>
#     </tr>
#     <tr>
#       <th>Guarda roupas</th>
#       <td>34900.24</td>
#     </tr>
#     <tr>
#       <th>Cama box</th>
#       <td>32476.36</td>
#     </tr>
#     <tr>
#       <th>Bicicleta</th>
#       <td>30611.11</td>
#     </tr>
#     <tr>
#       <th>Violão</th>
#       <td>24864.13</td>
#     </tr>
#     <tr>
#       <th>Cadeira de escritório</th>
#       <td>24706.82</td>
#     </tr>
#     <tr>
#       <th>Kit banquetas</th>
#       <td>16806.13</td>
#     </tr>
#     <tr>
#       <th>Cômoda</th>
#       <td>16306.77</td>
#     </tr>
#     <tr>
#       <th>Impressora</th>
#       <td>13846.69</td>
#     </tr>
#     <tr>
#       <th>Mesa de jantar</th>
#       <td>11516.31</td>
#     </tr>
#     <tr>
#       <th>Poltrona</th>
#       <td>11218.00</td>
#     </tr>
#     <tr>
#       <th>Jogo de panelas</th>
#       <td>10619.48</td>
#     </tr>
#     <tr>
#       <th>Assistente virtual</th>
#       <td>10572.47</td>
#     </tr>
#     <tr>
#       <th>Mesa de centro</th>
#       <td>10367.11</td>
#     </tr>
#     <tr>
#       <th>Smartwatch</th>
#       <td>10241.06</td>
#     </tr>
#     <tr>
#       <th>Jogo de tabuleiro</th>
#       <td>7749.58</td>
#     </tr>
#     <tr>
#       <th>Headset</th>
#       <td>7525.98</td>
#     </tr>
#     <tr>
#       <th>Mochila</th>
#       <td>5856.96</td>
#     </tr>
#     <tr>
#       <th>Pandeiro</th>
#       <td>4967.00</td>
#     </tr>
#     <tr>
#       <th>Fone de ouvido</th>
#       <td>4759.28</td>
#     </tr>
#     <tr>
#       <th>Panela de pressão</th>
#       <td>4676.44</td>
#     </tr>
#     <tr>
#       <th>Carrinho controle remoto</th>
#       <td>4362.38</td>
#     </tr>
#     <tr>
#       <th>Iniciando em programação</th>
#       <td>4169.96</td>
#     </tr>
#     <tr>
#       <th>Modelagem preditiva</th>
#       <td>3953.04</td>
#     </tr>
#     <tr>
#       <th>Ciência de dados com python</th>
#       <td>3198.42</td>
#     </tr>
#     <tr>
#       <th>Boneca bebê</th>
#       <td>3161.66</td>
#     </tr>
#     <tr>
#       <th>Bola de vôlei</th>
#       <td>3052.62</td>
#     </tr>
#     <tr>
#       <th>Copo térmico</th>
#       <td>2874.63</td>
#     </tr>
#     <tr>
#       <th>Bola de basquete</th>
#       <td>2788.23</td>
#     </tr>
#     <tr>
#       <th>Blocos de montar</th>
#       <td>2385.91</td>
#     </tr>
#     <tr>
#       <th>Faqueiro</th>
#       <td>2310.25</td>
#     </tr>
#     <tr>
#       <th>Dashboards com Power BI</th>
#       <td>2132.93</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>2056.69</td>
#     </tr>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>1717.05</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>1142.54</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>1027.41</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>

# %%
import pandas as pd
from IPython.display import display, HTML

# 1. Converter cada DataFrame para string HTML
html_valor_1 = top_produtos[0].to_html()
html_valor_2 = top_produtos[1].to_html()
html_valor_3 = top_produtos[2].to_html()
html_valor_4 = top_produtos[3].to_html()

# 3. Combinar os HTMLs em uma estrutura com CSS para layout lado a lado
# Utilizamos divs com a propriedade 'display: inline-block' para alinhar os elementos
# e 'margin' para dar espaço entre eles.
combined_html_3 = f"""
<div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Top 5 e 5 menos vendidos da Loja 01:</h3>
        {html_valor_1}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Top 5 e 5 menos vendidos da Loja 02:</h3>
        {html_valor_2}
    </div>
    <div style="display: inline-block; margin-right: 20px;">
        <h3>Top 5 e 5 menos vendidos da Loja 03:</h3>
        {html_valor_3}
    </div>
    <div style="display: inline-block;">
        <h3>Top 5 e 5 menos vendidos da Loja 04:</h3>
        {html_valor_4}
    </div>
</div>
"""

pd.set_option('display.max_colwidth', None)

# 4. Exibir o HTML combinado na célula do Colab
display(HTML(combined_html_3))
# Out:
# <div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Top 5 e 5 menos vendidos da Loja 01:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Venda Total em (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>189534.28</td>
#     </tr>
#     <tr>
#       <th>Geladeira</th>
#       <td>149524.28</td>
#     </tr>
#     <tr>
#       <th>Celular Plus X42</th>
#       <td>130536.40</td>
#     </tr>
#     <tr>
#       <th>Smart TV</th>
#       <td>89936.15</td>
#     </tr>
#     <tr>
#       <th>Lavadora de roupas</th>
#       <td>87711.30</td>
#     </tr>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>1907.42</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>1812.15</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>
#       <td>929.27</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>918.40</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>870.89</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Top 5 e 5 menos vendidos da Loja 02:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Venda Total em (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Celular Plus X42</th>
#       <td>150967.83</td>
#     </tr>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>137833.06</td>
#     </tr>
#     <tr>
#       <th>Geladeira</th>
#       <td>130176.48</td>
#     </tr>
#     <tr>
#       <th>Lavadora de roupas</th>
#       <td>89016.81</td>
#     </tr>
#     <tr>
#       <th>Smart TV</th>
#       <td>81522.94</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>2056.69</td>
#     </tr>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>1717.05</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>1142.54</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>1027.41</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>
#       <td>858.22</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block; margin-right: 20px;">
#         <h3>Top 5 e 5 menos vendidos da Loja 03:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Venda Total em (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Geladeira</th>
#       <td>133185.99</td>
#     </tr>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>128892.11</td>
#     </tr>
#     <tr>
#       <th>Celular Plus X42</th>
#       <td>124300.84</td>
#     </tr>
#     <tr>
#       <th>Smart TV</th>
#       <td>105116.46</td>
#     </tr>
#     <tr>
#       <th>Lava louças</th>
#       <td>85819.73</td>
#     </tr>
#     <tr>
#       <th>Blocos de montar</th>
#       <td>1649.81</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>1614.20</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>1137.76</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>1060.78</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>
#       <td>853.81</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style="display: inline-block;">
#         <h3>Top 5 e 5 menos vendidos da Loja 04:</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Venda Total em (R$)</th>
#     </tr>
#     <tr>
#       <th>Produto</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Celular Plus X42</th>
#       <td>128930.07</td>
#     </tr>
#     <tr>
#       <th>TV Led UHD 4K</th>
#       <td>120393.25</td>
#     </tr>
#     <tr>
#       <th>Smart TV</th>
#       <td>110387.57</td>
#     </tr>
#     <tr>
#       <th>Geladeira</th>
#       <td>100362.59</td>
#     </tr>
#     <tr>
#       <th>Tablet ABXY</th>
#       <td>75630.75</td>
#     </tr>
#     <tr>
#       <th>Jogo de copos</th>
#       <td>1962.24</td>
#     </tr>
#     <tr>
#       <th>Xadrez de madeira</th>
#       <td>1434.09</td>
#     </tr>
#     <tr>
#       <th>Dinossauro Rex</th>
#       <td>1143.94</td>
#     </tr>
#     <tr>
#       <th>Cubo mágico 8x8</th>
#       <td>997.38</td>
#     </tr>
#     <tr>
#       <th>Corda de pular</th>
#       <td>939.74</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
# </div>

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

medias_fretes = []
fretes_lojas  = []

# Agora basta rodarmos um for para fazer a soma de cada loja e printar o resultado na tela das vendas de cada uma:
for i in range(len(lojas)):
    medias_fretes.append(lojas[i]['Frete'].mean().round(2))
    fretes_lojas.append([f'Loja 0{i + 1}', medias_fretes[i]])

fretes_lojas = pd.DataFrame(fretes_lojas)
fretes_lojas.columns = ['Lojas', 'Média dos fretes']
fretes_lojas.sort_values(by='Média dos fretes', ascending=False, inplace = True)
fretes_lojas = fretes_lojas.reset_index(drop = True)
fretes_lojas
# Out:
#      Lojas  Média dos fretes
# 0  Loja 01             34.69
# 1  Loja 02             33.62
# 2  Loja 03             33.07
# 3  Loja 04             31.28

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 14})

# Dados de exemplo
valores = fretes_lojas['Média dos fretes']
rotulos = fretes_lojas['Lojas']

# Função personalizada para formatar os rótulos
# pct é a porcentagem calculada automaticamente pelo matplotlib para cada fatia
def formatar_valor(pct, valores):
    total = sum(valores)
    # Calcula o valor absoluto correspondente à porcentagem
    val = float(pct * total / 100.0)
    # Retorna o valor formatado como string, sem o símbolo de porcentagem
    return '{v:.2f}'.format(v=val)

plt.figure(figsize=(8, 4))

# Criando o gráfico de pizza
plt.pie(valores, 
        labels=rotulos, 
        autopct=(lambda p: f'R$ {formatar_valor(p, valores)}'), # Passa a função personalizada com os valores originais
        startangle=90
        )

# Garante que o gráfico seja desenhado como um círculo perfeito
plt.axis('equal')

# Adiciona um título
plt.title('Médias dos valores de fretes por Loja', fontsize = 18)

# Exibe o gráfico
plt.show()
